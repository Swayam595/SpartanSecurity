# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Importing Baltimore calls for service dataset with call given highest priority and dataset description

# %%
data = pd.read_csv('911_Police_Calls_for_Service.csv')
data.head()
# Out:
#    RecordID  CallNumber            CallDateTime Priority District  \
# 0       620  P190530647  02/22/2019 05:05:00 AM     High       CD
# 1      3408  P190521722  02/21/2019 01:15:00 PM     High       SE
# 2      6223  P190512183  02/20/2019 04:43:00 PM     High       WD
# 3      6305  P190512093  02/20/2019 04:12:00 PM     High       SD
# 4      6841  P190511474  02/20/2019 12:06:00 PM     High       ND
#
#        Description           IncidentLocation  ZipCode  \
# 0   COMMON ASSAULT      LIGHT ST/E LOMBARD ST  21202.0
# 1         OVERDOSE               0 N FRONT ST  21202.0
# 2     ARMED PERSON  W BALTIMORE ST/N MOUNT ST  21223.0
# 3  AUTO ACC/INJURY        KEY HY/E MCCOMAS ST  21230.0
# 4    ROBBERY ARMED   PARKWYRTH AV/OLD YORK RD  21218.0
#
#                    Neighborhood PoliceDistrict  PolicePost  CouncilDistrict  \
# 0                 Downtown West        Central       113.0             11.0
# 1                     Jonestown   Southeastern       211.0             12.0
# 2               Franklin Square        Western       711.0              9.0
# 3  Locust Point Industrial Area       Southern       943.0             11.0
# 4                       Waverly       Northern       543.0              4.0
#
#   SheriffDistricts Community_Statistical_Areas      Census_Tracts  \
# 0               D7         Downtown/Seton Hill   Census Tract 401
# 1               D7    Harbor East/Little Italy   Census Tract 302
# 2               D8         Southwest Baltimore  Census Tract 1901
# 3               D7             South Baltimore  Census Tract 2404
# 4               D2              Greater Govans   Census Tract 901
#
#        VRIZones                          Location
# 0           NaN         E LIGHT ST\nBALTIMORE, MD
# 1           NaN       0 N FRONT ST\nBALTIMORE, MD
# 2  Tri-District  W BALTIMORE ST\nST BALTIMORE, MD
# 3           NaN           E KEY HY\nBALTIMORE, MD
# 4           NaN       PARKWYRTH AV\nBALTIMORE, MD

# %%
data.describe()
# Out:
#            RecordID       ZipCode    PolicePost  CouncilDistrict
# count  8.894200e+04  68123.000000  88877.000000     88886.000000
# mean   5.716984e+06  21216.927352    520.903361         8.312119
# std    2.253743e+06     10.211230    264.702261         3.717028
# min    1.500000e+01  21201.000000    111.000000         1.000000
# 25%    6.121446e+06  21212.000000    312.000000         6.000000
# 50%    6.476531e+06  21217.000000    514.000000         9.000000
# 75%    6.826248e+06  21224.000000    742.000000        11.000000
# max    7.463676e+06  21287.000000    943.000000        14.000000

# %%
columns_in_use = ['CallDateTime', 'PoliceDistrict']
columns_in_use
# Out:
# ['CallDateTime', 'PoliceDistrict']

# %%
data = data[columns_in_use]
data.head()
# Out:
#              CallDateTime PoliceDistrict
# 0  02/22/2019 05:05:00 AM        Central
# 1  02/21/2019 01:15:00 PM   Southeastern
# 2  02/20/2019 04:43:00 PM        Western
# 3  02/20/2019 04:12:00 PM       Southern
# 4  02/20/2019 12:06:00 PM       Northern

# %%
data.describe()
# Out:
#                   CallDateTime PoliceDistrict
# count                    88942          88876
# unique                   77097              9
# top     05/16/2019 10:18:00 PM   Northeastern
# freq                         8          11963

# %% [markdown]
# ## Data Cleaning
#
# ### Droping rows with null values

# %%
columns = data.columns.tolist()

null_count = 0

for i in columns:
    rows_with_null_values = data[data[i].isnull()].index
    print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_null_values)))
    data = data.drop(rows_with_null_values, axis = 0)
    null_count += len(rows_with_null_values)

print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))
# Out:
# Number of Rows with null values in Column CallDateTime = 0
# Number of Rows with null values in Column PoliceDistrict = 66
# Number of rows droped =  66
# Number of rows after droping null values =  88876
# Data Frame Shape:
# 	 Number of Rows = 88876
# 	 Number of Columns = 2

# %% [markdown]
# ### Converting CallDateTime columns from string to pandas date time

# %%
data['CallDateTime']  = pd.to_datetime(data['CallDateTime'])
data.head()
# Out:
#          CallDateTime PoliceDistrict
# 0 2019-02-22 05:05:00        Central
# 1 2019-02-21 13:15:00   Southeastern
# 2 2019-02-20 16:43:00        Western
# 3 2019-02-20 16:12:00       Southern
# 4 2019-02-20 12:06:00       Northern

# %% [markdown]
# ### Creating Day of week, week number, month and year column from CallDateTime column

# %%
day_of_week = data['CallDateTime'].dt.dayofweek
week = data['CallDateTime'].dt.week
month = data['CallDateTime'].dt.month
year = data['CallDateTime'].dt.year

data['Day'] = day_of_week
data['Week'] = week
data['Month'] = month
data['Year'] = year

# %%
data.describe()
# Out:
#                 Day          Week         Month     Year
# count  88876.000000  88876.000000  88876.000000  88876.0
# mean       3.022560     26.048945      6.409256   2019.0
# std        1.993039     14.353009      3.289828      0.0
# min        0.000000      1.000000      1.000000   2019.0
# 25%        1.000000     14.000000      4.000000   2019.0
# 50%        3.000000     26.000000      6.000000   2019.0
# 75%        5.000000     38.000000      9.000000   2019.0
# max        6.000000     52.000000     12.000000   2019.0

# %% [markdown]
# ## Function to create a time series dataset, where police districts, week number and number of crime in that week are returned in a pandas dataframe

# %%
def ts_data_creation(group_by_parameter, data):
    parameters = {'Year':'Month', 'Month':'Week', 'Week':'Day', 'Day':'Error'}
    lower_group_by_parameter = parameters[group_by_parameter]
    
    if lower_group_by_parameter == 'Error':
        raise AttributeError('group_by_parameter cannot be "Day"')
        
    PoliceDistricts = set(data['PoliceDistrict'])
    ts_data = []
    for district in PoliceDistricts:
        for week_num, week_value in data[data['PoliceDistrict'] == district].groupby(group_by_parameter):
            total_weekly_cirmes = len(week_value)
            daily_crimes = [0] * 7
            for day_num, day_value in week_value.groupby(lower_group_by_parameter):
                total_daily_crime = len(day_value)
                daily_crimes[day_num] = total_daily_crime
            ts_data.append([district, week_num] + daily_crimes + [total_weekly_cirmes])
    ts_data = pd.DataFrame(ts_data, columns = ['PoliceDistrict', 'Week_Number', 'Monday','Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'NoOfCrimes'])
    return ts_data

# %% [markdown]
# ### Timeseries dataframe
#
# Dataframe shows total number of crimes, crimees per day in different police district in a given week of an year.

# %%
ts_data_week = ts_data_creation('Week', data)
ts_data_week.head()
# Out:
#   PoliceDistrict  Week_Number  Monday  Tuesday  Wednesday  Thursday  Friday  \
# 0        Western            1      14       66         25        24      28
# 1        Western            2      21       27         20        32      29
# 2        Western            3      20       19         27        21      37
# 3        Western            4      20       26         35        31      29
# 4        Western            5      14       19         20        17      28
#
#    Saturday  Sunday  NoOfCrimes
# 0        34      20         211
# 1        20      23         172
# 2        21      18         163
# 3        20      16         177
# 4        18      20         136

# %% [markdown]
# ### Crimes per week in different police district visualization

# %%
districts = set(ts_data_week['PoliceDistrict'])
df = pd.DataFrame()

for i in districts:
    values = ts_data_week[ts_data_week['PoliceDistrict'] == i]['NoOfCrimes'].tolist()
    index = ts_data_week[ts_data_week['PoliceDistrict'] == i]['Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year 2019', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('policeDistrictCrimes.jpg')
plt.show()

# %%
fig = plt.figure()
dist = list(districts)
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % dist[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('True_Crime_Baltimre.jpg')

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
districts = set(ts_data_week['PoliceDistrict'])
df_shift = pd.DataFrame()
temp_df = []
for district in districts:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[ts_data_week['PoliceDistrict'] == district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 21.82it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 22.94it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 23.05it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 24.32it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 25.85it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 22.48it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 24.27it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 24.67it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:00<00:00, 26.26it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (51, 754)
# (51, 348)
# (51, 754)
# (51, 347)
# (51, 754)
# (51, 346)
# (51, 754)
# (51, 347)
# (51, 754)
# (51, 346)
# (51, 754)
# (51, 343)
# (51, 754)
# (51, 345)
# (51, 754)
# (51, 346)
# (51, 754)
# (51, 347)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 10   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of random forest regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# 100%|██████████| 40/40 [00:07<00:00,  5.04it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.22it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.48it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.53it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.49it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.50it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.48it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.58it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.60it/s]
# Mean Squared Error for district Western = 744.89511
# Mean Absolute Error for district Western = 18.975
#
#
# Mean Squared Error for district Southern = 655.9031725000001
# Mean Absolute Error for district Southern = 20.147250000000003
#
#
# Mean Squared Error for district Central = 994.7421649999999
# Mean Absolute Error for district Central = 23.032999999999998
#
#
# Mean Squared Error for district Eastern = 860.7638075000001
# Mean Absolute Error for district Eastern = 25.409250000000004
#
#
# Mean Squared Error for district Northern = 660.3622725000001
# Mean Absolute Error for district Northern = 20.70275
#
#
# Mean Squared Error for district Northeastern = 1140.55744
# Mean Absolute Error for district Northeastern = 27.607500000000005
#
#
# Mean Squared Error for district Southeastern = 1037.808585
# Mean Absolute Error for district Southeastern = 27.3995
#
#
# Mean Squared Error for district Northwestern = 628.6824925000001
# Mean Absolute Error for district Northwestern = 20.48075
#
#
# Mean Squared Error for district Southwestern = 750.1258925
# Mean Absolute Error for district Southwestern = 24.03075
#
#
# Average of Mean Squared Error = 830.4267708333333
# Average of Mean Absolute Error = 23.08730555555556

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('Predicted_Crime_Vs_True_Crime_RFR.jpg')

# %% [markdown]
# #### Traing Multilayer Perceptron regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 10   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    MLPR = MLPRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        MLPR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = MLPR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of multilayer perceptron regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   3%|▎         | 1/37 [00:00<00:07,  4.65it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   5%|▌         | 2/37 [00:00<00:06,  5.12it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  11%|█         | 4/37 [00:00<00:05,  6.22it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:04,  7.26it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  22%|██▏       | 8/37 [00:00<00:03,  8.10it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  30%|██▉       | 11/37 [00:01<00:02,  9.29it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  35%|███▌      | 13/37 [00:01<00:02,  9.85it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  41%|████      | 15/37 [00:01<00:02,  8.43it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  49%|████▊     | 18/37 [00:01<00:01,  9.75it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  57%|█████▋    | 21/37 [00:01<00:01, 10.84it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  62%|██████▏   | 23/37 [00:02<00:01, 10.68it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  81%|████████  | 30/37 [00:02<00:00, 14.48it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  89%|████████▉ | 33/37 [00:02<00:00, 13.86it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  95%|█████████▍| 35/37 [00:02<00:00, 12.64it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:03<00:00, 11.93it/s]
#  11%|█         | 4/37 [00:00<00:01, 32.60it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  14%|█▎        | 5/37 [00:00<00:02, 15.49it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  19%|█▉        | 7/37 [00:00<00:02, 14.47it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  24%|██▍       | 9/37 [00:00<00:02, 13.80it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  30%|██▉       | 11/37 [00:00<00:01, 13.42it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  38%|███▊      | 14/37 [00:00<00:01, 14.00it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  43%|████▎     | 16/37 [00:01<00:01, 13.24it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  59%|█████▉    | 22/37 [00:01<00:01, 11.73it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  65%|██████▍   | 24/37 [00:01<00:01, 11.48it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  70%|███████   | 26/37 [00:01<00:00, 11.45it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  76%|███████▌  | 28/37 [00:02<00:00, 10.89it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  84%|████████▍ | 31/37 [00:02<00:00, 11.95it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  89%|████████▉ | 33/37 [00:02<00:00, 11.93it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  95%|█████████▍| 35/37 [00:02<00:00, 11.65it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:03<00:00, 12.04it/s]
#   5%|▌         | 2/37 [00:00<00:02, 15.58it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   8%|▊         | 3/37 [00:00<00:02, 11.39it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  22%|██▏       | 8/37 [00:00<00:02, 13.42it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  27%|██▋       | 10/37 [00:00<00:02, 13.09it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  35%|███▌      | 13/37 [00:00<00:01, 13.65it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  51%|█████▏    | 19/37 [00:01<00:01, 15.79it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  57%|█████▋    | 21/37 [00:01<00:01, 10.37it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  62%|██████▏   | 23/37 [00:01<00:01, 10.10it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  84%|████████▍ | 31/37 [00:02<00:00, 14.06it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  92%|█████████▏| 34/37 [00:02<00:00, 13.69it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  97%|█████████▋| 36/37 [00:02<00:00, 12.38it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:02<00:00, 13.86it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   5%|▌         | 2/37 [00:00<00:03,  8.96it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  19%|█▉        | 7/37 [00:00<00:02, 10.57it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  22%|██▏       | 8/37 [00:00<00:03,  8.15it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  24%|██▍       | 9/37 [00:00<00:03,  7.14it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  27%|██▋       | 10/37 [00:01<00:04,  6.21it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  43%|████▎     | 16/37 [00:01<00:02,  8.87it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  51%|█████▏    | 19/37 [00:01<00:01,  9.46it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  57%|█████▋    | 21/37 [00:02<00:02,  7.78it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  78%|███████▊  | 29/37 [00:02<00:00, 11.36it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  84%|████████▍ | 31/37 [00:02<00:00, 10.43it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:03<00:00, 11.79it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:02, 13.37it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  22%|██▏       | 8/37 [00:00<00:02, 12.85it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  27%|██▋       | 10/37 [00:00<00:02, 12.48it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  32%|███▏      | 12/37 [00:00<00:02, 10.82it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  38%|███▊      | 14/37 [00:01<00:02, 10.01it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  46%|████▌     | 17/37 [00:01<00:01, 10.70it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  68%|██████▊   | 25/37 [00:01<00:00, 14.66it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  76%|███████▌  | 28/37 [00:01<00:00, 13.44it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  81%|████████  | 30/37 [00:02<00:00, 12.05it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  86%|████████▋ | 32/37 [00:02<00:00, 11.53it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  97%|█████████▋| 36/37 [00:02<00:00, 12.01it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:02<00:00, 12.97it/s]
#  11%|█         | 4/37 [00:00<00:00, 35.14it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:01, 19.79it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  22%|██▏       | 8/37 [00:00<00:01, 15.54it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  27%|██▋       | 10/37 [00:00<00:02, 12.99it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  32%|███▏      | 12/37 [00:01<00:02,  9.29it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  35%|███▌      | 13/37 [00:01<00:03,  7.87it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  41%|████      | 15/37 [00:01<00:02,  8.10it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  49%|████▊     | 18/37 [00:01<00:02,  9.14it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  54%|█████▍    | 20/37 [00:01<00:01,  8.99it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  59%|█████▉    | 22/37 [00:02<00:01,  8.97it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  65%|██████▍   | 24/37 [00:02<00:01,  9.30it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  76%|███████▌  | 28/37 [00:02<00:00, 10.70it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  81%|████████  | 30/37 [00:02<00:00,  8.19it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  95%|█████████▍| 35/37 [00:03<00:00,  8.62it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:03<00:00, 10.03it/s]
#  11%|█         | 4/37 [00:00<00:00, 33.13it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:01, 20.58it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  24%|██▍       | 9/37 [00:00<00:01, 17.50it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  35%|███▌      | 13/37 [00:00<00:01, 16.55it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  41%|████      | 15/37 [00:00<00:01, 14.19it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  46%|████▌     | 17/37 [00:01<00:01, 12.95it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  65%|██████▍   | 24/37 [00:01<00:00, 15.24it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  76%|███████▌  | 28/37 [00:01<00:00, 15.49it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  84%|████████▍ | 31/37 [00:02<00:00, 15.17it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  92%|█████████▏| 34/37 [00:02<00:00, 14.41it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  97%|█████████▋| 36/37 [00:02<00:00, 12.51it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:02<00:00, 14.00it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   3%|▎         | 1/37 [00:00<00:05,  6.70it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:573: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
#   5%|▌         | 2/37 [00:00<00:05,  6.70it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  11%|█         | 4/37 [00:00<00:04,  7.56it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  14%|█▎        | 5/37 [00:00<00:04,  7.23it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:04,  6.79it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  24%|██▍       | 9/37 [00:01<00:03,  7.47it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  30%|██▉       | 11/37 [00:01<00:03,  7.90it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  32%|███▏      | 12/37 [00:01<00:03,  7.27it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  49%|████▊     | 18/37 [00:01<00:01, 10.43it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  54%|█████▍    | 20/37 [00:02<00:01, 10.51it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  59%|█████▉    | 22/37 [00:02<00:01, 10.53it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  65%|██████▍   | 24/37 [00:02<00:01, 10.49it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  70%|███████   | 26/37 [00:02<00:01, 10.45it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  76%|███████▌  | 28/37 [00:02<00:00,  9.78it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  81%|████████  | 30/37 [00:03<00:00,  9.36it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  92%|█████████▏| 34/37 [00:03<00:00, 10.42it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  97%|█████████▋| 36/37 [00:03<00:00,  8.07it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:03<00:00,  9.41it/s]
#   0%|          | 0/37 [00:00<?, ?it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#   5%|▌         | 2/37 [00:00<00:03,  9.54it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  14%|█▎        | 5/37 [00:00<00:03, 10.47it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  16%|█▌        | 6/37 [00:00<00:03,  8.48it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  19%|█▉        | 7/37 [00:00<00:04,  7.36it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  24%|██▍       | 9/37 [00:00<00:03,  7.99it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  27%|██▋       | 10/37 [00:01<00:03,  7.37it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  32%|███▏      | 12/37 [00:01<00:03,  8.00it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  35%|███▌      | 13/37 [00:01<00:03,  7.16it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  57%|█████▋    | 21/37 [00:01<00:01, 11.02it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  68%|██████▊   | 25/37 [00:02<00:00, 12.16it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#  73%|███████▎  | 27/37 [00:02<00:00, 11.37it/s]/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# 100%|██████████| 37/37 [00:02<00:00, 13.36it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-b026c78163ea> in <module>
#      24     dist = list(districts)[i]
#      25     temp_pred = [np.nan] + y_pred[i]
# ---> 26     MSE = mean_squared_error(y_true[11:], temp_pred[11:])
#      27     MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
#      28     prediction[dist] = {'MSE': MSE, 'MAE': MAE}
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [40, 37]

# %% [markdown]
# #### MLPR prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('Predicted_Crime_Vs_True_Crime_MLPRegressor.jpg')

# %% [markdown]
# #### Traing support vector regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 10   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    SVRegr = SVR()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        SVRegr.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = SVRegr.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of support vector regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))
    
#### Finding average of MSE and MAE
    
total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 404.39it/s]
# 100%|██████████| 40/40 [00:00<00:00, 498.74it/s]
# 100%|██████████| 40/40 [00:00<00:00, 497.08it/s]
# 100%|██████████| 40/40 [00:00<00:00, 495.23it/s]
# 100%|██████████| 40/40 [00:00<00:00, 437.14it/s]
# 100%|██████████| 40/40 [00:00<00:00, 477.37it/s]
# 100%|██████████| 40/40 [00:00<00:00, 493.38it/s]
# 100%|██████████| 40/40 [00:00<00:00, 487.30it/s]
# 100%|██████████| 40/40 [00:00<00:00, 496.31it/s]
# Mean Squared Error for district Central = 1543.9425091925248
# Mean Absolute Error for district Central = 30.422715684410075
#
#
# Mean Squared Error for district Northern = 786.6078820754083
# Mean Absolute Error for district Northern = 22.533179255788564
#
#
# Mean Squared Error for district Northwestern = 1030.636649200936
# Mean Absolute Error for district Northwestern = 27.81428091239883
#
#
# Mean Squared Error for district Western = 1328.682380770474
# Mean Absolute Error for district Western = 28.597860769492968
#
#
# Mean Squared Error for district Southeastern = 1713.9893324729921
# Mean Absolute Error for district Southeastern = 35.27948699848812
#
#
# Mean Squared Error for district Southwestern = 1541.4045176876284
# Mean Absolute Error for district Southwestern = 32.688891030835286
#
#
# Mean Squared Error for district Northeastern = 1573.6935122754307
# Mean Absolute Error for district Northeastern = 31.782535521362966
#
#
# Mean Squared Error for district Southern = 1063.8944056037328
# Mean Absolute Error for district Southern = 26.19665583868211
#
#
# Mean Squared Error for district Eastern = 990.8713568218488
# Mean Absolute Error for district Eastern = 26.986021933993964
#
#
# Average of Mean Squared Error = 1285.9691717889973
# Average of Mean Absolute Error = 29.14462532727255

# %% [markdown]
# #### SVR visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('Predicted_Crime_Vs_True_Crime_SVR.jpg')

# %% [markdown]
# ## Recursive Feature Elimination From Random Forest Regressor
#
# Since Random Forest Regressor Outperforms other model we will use it for eliminating features recursively.
#
# ### Library Dependencies for Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

# %%
district_imp_features = {}
district_list = list(districts) 
j = 0
for i in ts_features:
    model = RandomForestRegressor()
    model = RFE(model, 10)
    model = model.fit(i[0], i[1])
    imp_columns = i[0].columns[model.support_ == True]
    district = district_list[j]
    district_imp_features[district] = imp_columns
    j += 1
    
district_imp_features = pd.DataFrame(district_imp_features)
district_imp_features
# Out:
#                                              Central  \
# 0  value__agg_linear_trend__f_agg_"mean"__chunk_l...
# 1  value__agg_linear_trend__f_agg_"var"__chunk_le...
# 2  value__change_quantiles__f_agg_"var"__isabs_Tr...
# 3  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 4       value__fft_coefficient__coeff_6__attr_"real"
# 5                                    value__kurtosis
# 6                 value__linear_trend__attr_"rvalue"
# 7                  value__linear_trend__attr_"slope"
# 8  value__percentage_of_reoccurring_datapoints_to...
# 9    value__time_reversal_asymmetry_statistic__lag_2
#
#                                             Northern  \
# 0  value__agg_linear_trend__f_agg_"max"__chunk_le...
# 1  value__agg_linear_trend__f_agg_"min"__chunk_le...
# 2  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 3  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 4  value__energy_ratio_by_chunks__num_segments_10...
# 5      value__fft_coefficient__coeff_3__attr_"angle"
# 6       value__fft_coefficient__coeff_7__attr_"imag"
# 7        value__fft_coefficient__coeff_8__attr_"abs"
# 8                   value__first_location_of_minimum
# 9                    value__last_location_of_maximum
#
#                                         Northwestern  \
# 0  value__change_quantiles__f_agg_"mean"__isabs_F...
# 1  value__change_quantiles__f_agg_"var"__isabs_Fa...
# 2  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 3  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 4  value__energy_ratio_by_chunks__num_segments_10...
# 5       value__fft_coefficient__coeff_9__attr_"real"
# 6                   value__first_location_of_maximum
# 7                 value__linear_trend__attr_"rvalue"
# 8                  value__linear_trend__attr_"slope"
# 9                                 value__mean_change
#
#                                              Western  \
# 0  value__change_quantiles__f_agg_"mean"__isabs_F...
# 1  value__change_quantiles__f_agg_"mean"__isabs_T...
# 2  value__change_quantiles__f_agg_"var"__isabs_Fa...
# 3  value__change_quantiles__f_agg_"var"__isabs_Fa...
# 4                     value__cid_ce__normalize_False
# 5  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 6  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 7  value__energy_ratio_by_chunks__num_segments_10...
# 8                 value__linear_trend__attr_"rvalue"
# 9                 value__spkt_welch_density__coeff_5
#
#                                         Southeastern  \
# 0  value__agg_linear_trend__f_agg_"var"__chunk_le...
# 1  value__augmented_dickey_fuller__autolag_"AIC"_...
# 2  value__change_quantiles__f_agg_"mean"__isabs_F...
# 3  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 4  value__energy_ratio_by_chunks__num_segments_10...
# 5      value__fft_coefficient__coeff_3__attr_"angle"
# 6       value__fft_coefficient__coeff_3__attr_"imag"
# 7                   value__first_location_of_minimum
# 8                    value__last_location_of_minimum
# 9                 value__linear_trend__attr_"rvalue"
#
#                                         Southwestern  \
# 0  value__change_quantiles__f_agg_"mean"__isabs_T...
# 1  value__change_quantiles__f_agg_"var"__isabs_Fa...
# 2  value__change_quantiles__f_agg_"var"__isabs_Fa...
# 3  value__change_quantiles__f_agg_"var"__isabs_Tr...
# 4  value__change_quantiles__f_agg_"var"__isabs_Tr...
# 5  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 6        value__fft_coefficient__coeff_6__attr_"abs"
# 7       value__fft_coefficient__coeff_8__attr_"imag"
# 8                 value__linear_trend__attr_"rvalue"
# 9                             value__quantile__q_0.7
#
#                                         Northeastern  \
# 0  value__agg_autocorrelation__f_agg_"mean"__maxl...
# 1                      value__autocorrelation__lag_6
# 2  value__cwt_coefficients__widths_(2, 5, 10, 20)...
# 3  value__energy_ratio_by_chunks__num_segments_10...
# 4      value__fft_coefficient__coeff_1__attr_"angle"
# 5      value__fft_coefficient__coeff_7__attr_"angle"
# 6                 value__linear_trend__attr_"rvalue"
# 7              value__partial_autocorrelation__lag_5
# 8    value__time_reversal_asymmetry_statistic__lag_2
# 9    value__time_reversal_asymmetry_statistic__lag_3
#
#                                             Southern  \
# 0                     value__absolute_sum_of_changes
# 1  value__agg_linear_trend__f_agg_"min"__chunk_le...
# 2             value__approximate_entropy__m_2__r_0.3
# 3  value__change_quantiles__f_agg_"mean"__isabs_F...
# 4  value__change_quantiles__f_agg_"mean"__isabs_T...
# 5  value__change_quantiles__f_agg_"var"__isabs_Tr...
# 6                     value__cid_ce__normalize_False
# 7        value__fft_coefficient__coeff_2__attr_"abs"
# 8        value__fft_coefficient__coeff_8__attr_"abs"
# 9                           value__number_peaks__n_5
#
#                                              Eastern
# 0                      value__autocorrelation__lag_3
# 1  value__change_quantiles__f_agg_"mean"__isabs_F...
# 2       value__fft_coefficient__coeff_6__attr_"real"
# 3       value__fft_coefficient__coeff_7__attr_"real"
# 4      value__fft_coefficient__coeff_8__attr_"angle"
# 5                    value__last_location_of_minimum
# 6                 value__linear_trend__attr_"rvalue"
# 7                       value__number_cwt_peaks__n_5
# 8              value__partial_autocorrelation__lag_5
# 9              value__sum_of_reoccurring_data_points
