# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
if not os.path.exists('../Graphs/Sub_Crime/Homicide'):
    os.makedirs('../Graphs/Sub_Crime/Homicide')

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../Clean Dataset/Sub Crimes By Neighborhood/Homicide_By_Neighborhood.csv')
data.head()
# Out:
#     CrimeDate CrimeTime CrimeCode           Location Description  \
# 0  06/06/2020  21:10:00        1K  4500 E FAYETTE ST    HOMICIDE
# 1  06/05/2020  21:33:00        1A    1700 GORSUCH AV    HOMICIDE
# 2  06/03/2020  00:45:00        1A  700 W SARATOGA ST    HOMICIDE
# 3  06/02/2020  13:23:00        1A      800 MCKEAN AV    HOMICIDE
# 4  06/02/2020  23:00:00        1A     5600 HADDON AV    HOMICIDE
#
#   Inside/Outside   Weapon   Post   District          Neighborhood  Longitude  \
# 0        Outside    KNIFE  232.0  SOUTHEAST               KRESSON -76.559706
# 1        Outside  FIREARM  411.0  NORTHEAST  COLDSTREAM HOMESTEAD -76.594123
# 2        Outside  FIREARM  122.0    CENTRAL             POPPLETON -76.627939
# 3         Inside  FIREARM  722.0    WESTERN           HARLEM PARK -76.646685
# 4        Outside  FIREARM  634.0  NORTHWEST            GROVE PARK -76.704238
#
#     Latitude  Location 1      Premise vri_name1  Total Incidents
# 0  39.295231         NaN  PUBLIC AREA       NaN                1
# 1  39.320986         NaN       STREET       NaN                1
# 2  39.292785         NaN       STREET       NaN                1
# 3  39.298383         NaN     DWELLING       NaN                1
# 4  39.337824         NaN       STREET       NaN                1

# %%
data.describe()
# Out:
#               Post    Longitude     Latitude  Location 1  Total Incidents
# count  1686.000000  1919.000000  1919.000000         0.0           1922.0
# mean    556.031435   -76.626815    39.307408         NaN              1.0
# std     241.177735     0.041337     0.027093         NaN              0.0
# min     111.000000   -76.710589    39.215228         NaN              1.0
# 25%     331.250000   -76.661391    39.292508         NaN              1.0
# 50%     613.000000   -76.632661    39.306010         NaN              1.0
# 75%     734.000000   -76.595681    39.323716         NaN              1.0
# max     942.000000   -76.530489    39.371011         NaN              1.0

# %%
columns_in_use = ['CrimeDate', 'District']
columns_in_use
# Out:
# ['CrimeDate', 'District']

# %%
data = data[columns_in_use]
data.head()
# Out:
#     CrimeDate   District
# 0  06/06/2020  SOUTHEAST
# 1  06/05/2020  NORTHEAST
# 2  06/03/2020    CENTRAL
# 3  06/02/2020    WESTERN
# 4  06/02/2020  NORTHWEST

# %%
data.describe()
# Out:
#          CrimeDate District
# count         1922     1922
# unique        1257        9
# top     02/10/2020  WESTERN
# freq             6      303

# %%
null_count = 0

for i in columns_in_use:
    rows_with_null_values = data[data[i].isnull()].index
    print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_null_values)))
    data = data.drop(rows_with_null_values, axis = 0)
    null_count += len(rows_with_null_values)

print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))
# Out:
# Number of Rows with null values in Column CrimeDate = 0
# Number of Rows with null values in Column District = 0
# Number of rows droped =  0
# Number of rows after droping null values =  1922
# Data Frame Shape:
# 	 Number of Rows = 1922
# 	 Number of Columns = 2

# %% [markdown]
# ## Droping Rows with Unknown Police Districts

# %%
rows_with_unknowon_district = data[data['District'] == 'UNKNOWN'].index
print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_unknowon_district)))
data = data.drop(rows_with_unknowon_district, axis = 0)

null_count += len(rows_with_unknowon_district)
print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))
# Out:
# Number of Rows with null values in Column District = 0
# Number of rows droped =  0
# Number of rows after droping null values =  1922
# Data Frame Shape:
# 	 Number of Rows = 1922
# 	 Number of Columns = 2

# %%
data['CrimeDate']  = pd.to_datetime(data['CrimeDate'])
data.head()
# Out:
#    CrimeDate   District
# 0 2020-06-06  SOUTHEAST
# 1 2020-06-05  NORTHEAST
# 2 2020-06-03    CENTRAL
# 3 2020-06-02    WESTERN
# 4 2020-06-02  NORTHWEST

# %% [markdown]
# ## Creating Different Time features

# %%
day_of_week = data['CrimeDate'].dt.dayofweek
week = data['CrimeDate'].dt.week
month = data['CrimeDate'].dt.month
year = data['CrimeDate'].dt.year

data['Day'] = day_of_week
data['Week'] = week
data['Month'] = month
data['Year'] = year

data.head()
# Out:
#    CrimeDate   District  Day  Week  Month  Year
# 0 2020-06-06  SOUTHEAST    5    23      6  2020
# 1 2020-06-05  NORTHEAST    4    23      6  2020
# 2 2020-06-03    CENTRAL    2    23      6  2020
# 3 2020-06-02    WESTERN    1    23      6  2020
# 4 2020-06-02  NORTHWEST    1    23      6  2020

# %% [markdown]
# ## Consider data from 2014 and beyond

# %%
data = data[data['Year']>= 2014]

# %%
data.describe()
# Out:
#                Day         Week        Month         Year
# count  1922.000000  1922.000000  1922.000000  1922.000000
# mean      2.941207    26.623829     6.562435  2016.890219
# std       2.000307    14.539773     3.344758     1.796786
# min       0.000000     1.000000     1.000000  2014.000000
# 25%       1.000000    15.000000     4.000000  2015.000000
# 50%       3.000000    27.000000     7.000000  2017.000000
# 75%       5.000000    39.000000     9.000000  2018.000000
# max       6.000000    53.000000    12.000000  2020.000000

# %% [markdown]
# ## Creating Times Series Dataset

# %%
def ts_data_creation(group_by_parameter, data):
    if group_by_parameter == 'Week' or group_by_parameter == 'Month':
        pass
    else:
        raise AttributeError('group_by_parameter')
    
    if group_by_parameter == 'Week':
        parameter_name = 'Week_Number'
    else:
        parameter_name = 'Month_Number'
        
    PoliceDistricts = set(data['District'])
    ts_data = {}
    for district in PoliceDistricts:
        ts_data_temp = []
        for year_num, year_value in data[data['District'] == district].groupby('Year'):
            for parameter_num, parameter_value in year_value[year_value['District'] == district].groupby(group_by_parameter):
                total_crimes = len(parameter_value)
                year_parameter_num = "%s_%s"%(year_num, parameter_num)
                ts_data_temp.append([year_num] + [district, parameter_num, year_parameter_num] + [total_crimes])
        ts_data_temp = pd.DataFrame(ts_data_temp, columns = ['Year', 'PoliceDistrict', parameter_name, 'Year_%s'%parameter_name, 'NoOfCrimes'])
        ts_data[district] = ts_data_temp
    
    return ts_data

# %%
ts_data_week = ts_data_creation('Week', data)
ts_data_week
# Out:
# {'WESTERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2
':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      SOUTHWEST            1           2014_1           2
#  1    2014      SOUTHWEST            2           2014_2           2
#  2    2014      SOUTHWEST            5           2014_5           1
#  3    2014      SOUTHWEST            9           2014_9           1
#  4    2014      SOUTHWEST           10          2014_10           1
#  ..    ...            ...          ...              ...         ...
#  181  2020      SOUTHWEST           17          2020_17           1
#  182  2020      SOUTHWEST           18          2020_18           2
#  183  2020      SOUTHWEST           19          2020_19           1
#  184  2020      SOUTHWEST           21          2020_21           2
#  185  2020      SOUTHWEST           22          2020_22           2
#
#  [186 rows x 5 columns],
#  'EASTERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014        EASTERN            1           2014_1           2
#  1    2014        EASTERN            8           2014_8           1
#  2    2014        EASTERN           10          2014_10           1
#  3    2014        EASTERN           11          2014_11           1
#  4    2014        EASTERN           14          2014_14           1
#  ..    ...            ...          ...              ...         ...
#  174  2020        EASTERN           13          2020_13           2
#  175  2020        EASTERN           15          2020_15           1
#  176  2020        EASTERN           19          2020_19           3
#  177  2020        EASTERN           20          2020_20           1
#  178  2020        EASTERN           21          2020_21           2
#
#  [179 rows x 5 columns],
#  'SOUTHERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014       SOUTHERN            1           2014_1           1
#  1    2014       SOUTHERN            5           2014_5           2
#  2    2014       SOUTHERN            9           2014_9           1
#  3    2014       SOUTHERN           13          2014_13           1
#  4    2014       SOUTHERN           14          2014_14           1
#  ..    ...            ...          ...              ...         ...
#  138  2020       SOUTHERN           14          2020_14           1
#  139  2020       SOUTHERN           15          2020_15           3
#  140  2020       SOUTHERN           18          2020_18           1
#  141  2020       SOUTHERN           19          2020_19           3
#  142  2020       SOUTHERN           22          2020_22           1
#
#  [143 rows x 5 columns]}

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      NORTHEAST            1           2014_1           1
# 1  2014      NORTHEAST            2           2014_2           2
# 2  2014      NORTHEAST            4           2014_4           1
# 3  2014      NORTHEAST            7           2014_7           1
# 4  2014      NORTHEAST           14          2014_14           1

# %%
districts = set(data['District'])
df = pd.DataFrame()

for i in districts:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year 2019', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../graphs/Sub_Crime/Homicide/policeDistrictCrimes.jpg')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
fig = plt.figure()
dist = list(districts)
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % dist[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Sub_Crime/Homicide/True_Crime_Baltimre.jpg')

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
districts = set(data['District'])
df_shift = pd.DataFrame()
temp_df = []
for district in districts:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  9.40it/s]
# Feature Extraction: 100%|██████████| 17/17 [00:01<00:00, 13.54it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:01<00:00, 16.56it/s]
# Feature Extraction: 100%|██████████| 19/19 [00:02<00:00,  8.85it/s]
# Feature Extraction: 100%|██████████| 19/19 [00:01<00:00, 11.61it/s]
# Feature Extraction: 100%|██████████| 19/19 [00:02<00:00,  8.02it/s]
# Feature Extraction: 100%|██████████| 19/19 [00:03<00:00,  6.17it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:02<00:00,  8.83it/s]
# Feature Extraction: 100%|██████████| 18/18 [00:01<00:00, 10.02it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (195, 754)
# (195, 327)
# (102, 754)
# (102, 313)
# (96, 754)
# (96, 307)
# (185, 754)
# (185, 326)
# (109, 754)
# (109, 302)
# (163, 754)
# (163, 340)
# (185, 754)
# (185, 330)
# (178, 754)
# (178, 327)
# (142, 754)
# (142, 325)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 284   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[285:], temp_pred[285:])
    MAE = mean_absolute_error(y_true[285:], temp_pred[285:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Current District Number = 1
# Current District Number = 2
# Current District Number = 3
# Current District Number = 4
# Current District Number = 5
# Current District Number = 6
# Current District Number = 7
# Current District Number = 8
# Current District Number = 9
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d038690a1fd4> in <module>
#      25     dist = list(districts)[i]
#      26     temp_pred = [np.nan] + y_pred[i]
# ---> 27     MSE = mean_squared_error(y_true[285:], temp_pred[285:])
#      28     MAE = mean_absolute_error(y_true[285:], temp_pred[285:])
#      29     prediction[dist] = {'MSE': MSE, 'MAE': MAE}
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      87
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     584                              " minimum of %d is required%s."
#     585                              % (n_samples, array.shape, ensure_min_samples,
# --> 586                                 context))
#     587
#     588     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Sub_Crime/Homicide/Predicted_Crime_Vs_True_Crime_RFR.jpg')
