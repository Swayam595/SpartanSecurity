# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
if not os.path.exists('../Graphs'):
    os.mkdir('../Graphs')

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../Clean Dataset/BPD_Part_1_Victim_Based_Crime_Data.csv')
data.head()

# %%
data.describe()

# %%
columns_in_use = ['CrimeDate', 'District']
columns_in_use

# %%
data = data[columns_in_use]
data.head()

# %%
data.describe()

# %%
null_count = 0

for i in columns_in_use:
    rows_with_null_values = data[data[i].isnull()].index
    print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_null_values)))
    data = data.drop(rows_with_null_values, axis = 0)
    null_count += len(rows_with_null_values)

print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))

# %% [markdown]
# ## Droping Rows with Unknown Police Districts

# %%
rows_with_unknowon_district = data[data['District'] == 'UNKNOWN'].index
print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_unknowon_district)))
data = data.drop(rows_with_unknowon_district, axis = 0)

null_count += len(rows_with_unknowon_district)
print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))

# %%
data['CrimeDate']  = pd.to_datetime(data['CrimeDate'])
data.head()

# %% [markdown]
# ## Creating Different Time features

# %%
day_of_week = data['CrimeDate'].dt.dayofweek
week = data['CrimeDate'].dt.week
month = data['CrimeDate'].dt.month
year = data['CrimeDate'].dt.year

data['Day'] = day_of_week
data['Week'] = week
data['Month'] = month
data['Year'] = year

data.head()

# %% [markdown]
# ## Consider data from 2014 and beyond

# %%
data = data[data['Year']>= 2014]

# %%
data.describe()

# %% [markdown]
# ## Creating Times Series Dataset

# %%
def ts_data_creation(group_by_parameter, data):
    if group_by_parameter == 'Week' or group_by_parameter == 'Month':
        pass
    else:
        raise AttributeError('group_by_parameter')
    
    if group_by_parameter == 'Week':
        parameter_name = 'Week_Number'
    else:
        parameter_name = 'Month_Number'
        
    PoliceDistricts = set(data['District'])
    ts_data = {}
    for district in PoliceDistricts:
        ts_data_temp = []
        for year_num, year_value in data[data['District'] == district].groupby('Year'):
            for parameter_num, parameter_value in year_value[year_value['District'] == district].groupby(group_by_parameter):
                total_crimes = len(parameter_value)
                year_parameter_num = "%s_%s"%(year_num, parameter_num)
                ts_data_temp.append([year_num] + [district, parameter_num, year_parameter_num] + [total_crimes])
        ts_data_temp = pd.DataFrame(ts_data_temp, columns = ['Year', 'PoliceDistrict', parameter_name, 'Year_%s'%parameter_name, 'NoOfCrimes'])
        ts_data[district] = ts_data_temp
    
    return ts_data

# %%
ts_data_week = ts_data_creation('Week', data)
ts_data_week

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()

# %%
districts = set(data['District'])
df = pd.DataFrame()

for i in districts:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year 2019', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../graphs/policeDistrictCrimes.jpg')
plt.show()

# %%
fig = plt.figure()
dist = list(districts)
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % dist[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/True_Crime_Baltimre.jpg')

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
districts = set(data['District'])
df_shift = pd.DataFrame()
temp_df = []
for district in districts:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 310   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of random forest regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[311:], temp_pred[311:])
    MAE = mean_absolute_error(y_true[311:], temp_pred[311:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:50,  2.16s/it]
#
#   4%|▍         | 2/52 [00:04<01:48,  2.17s/it]
#
#   6%|▌         | 3/52 [00:06<01:46,  2.16s/it]
#
#   8%|▊         | 4/52 [00:08<01:44,  2.18s/it]
#
#  10%|▉         | 5/52 [00:10<01:42,  2.18s/it]
#
#  12%|█▏        | 6/52 [00:13<01:40,  2.19s/it]
#
#  13%|█▎        | 7/52 [00:15<01:39,  2.21s/it]
#
#  15%|█▌        | 8/52 [00:17<01:39,  2.25s/it]
#
#  17%|█▋        | 9/52 [00:19<01:36,  2.24s/it]
#
#  19%|█▉        | 10/52 [00:22<01:35,  2.27s/it]
#
#  21%|██        | 11/52 [00:24<01:32,  2.25s/it]
#
#  23%|██▎       | 12/52 [00:26<01:30,  2.26s/it]
#
#  25%|██▌       | 13/52 [00:29<01:28,  2.27s/it]
#
#  27%|██▋       | 14/52 [00:31<01:27,  2.30s/it]
#
#  29%|██▉       | 15/52 [00:33<01:25,  2.31s/it]
#
#  31%|███       | 16/52 [00:36<01:23,  2.31s/it]
#
#  33%|███▎      | 17/52 [00:38<01:21,  2.32s/it]
#
#  35%|███▍      | 18/52 [00:40<01:19,  2.35s/it]
#
#  37%|███▋      | 19/52 [00:43<01:17,  2.36s/it]
#
#  38%|███▊      | 20/52 [00:45<01:15,  2.35s/it]
#
#  40%|████      | 21/52 [00:47<01:13,  2.37s/it]
#
#  42%|████▏     | 22/52 [00:50<01:10,  2.35s/it]
#
#  44%|████▍     | 23/52 [00:52<01:07,  2.34s/it]
#
#  46%|████▌     | 24/52 [00:54<01:05,  2.35s/it]
#
#  48%|████▊     | 25/52 [00:57<01:03,  2.33s/it]
#
#  50%|█████     | 26/52 [00:59<01:00,  2.31s/it]
#
#  52%|█████▏    | 27/52 [01:01<00:58,  2.32s/it]
#
#  54%|█████▍    | 28/52 [01:04<00:55,  2.32s/it]
#
#  56%|█████▌    | 29/52 [01:06<00:53,  2.32s/it]
#
#  58%|█████▊    | 30/52 [01:08<00:51,  2.35s/it]
#
#  60%|█████▉    | 31/52 [01:11<00:49,  2.36s/it]
#
#  62%|██████▏   | 32/52 [01:13<00:47,  2.37s/it]
#
#  63%|██████▎   | 33/52 [01:16<00:45,  2.38s/it]
#
#  65%|██████▌   | 34/52 [01:18<00:43,  2.39s/it]
#
#  67%|██████▋   | 35/52 [01:20<00:40,  2.39s/it]
#
#  69%|██████▉   | 36/52 [01:23<00:38,  2.38s/it]
#
#  71%|███████   | 37/52 [01:25<00:35,  2.39s/it]
#
#  73%|███████▎  | 38/52 [01:28<00:33,  2.39s/it]
#
#  75%|███████▌  | 39/52 [01:30<00:31,  2.40s/it]
#
#  77%|███████▋  | 40/52 [01:32<00:28,  2.40s/it]
#
#  79%|███████▉  | 41/52 [01:35<00:26,  2.41s/it]
#
#  81%|████████  | 42/52 [01:37<00:24,  2.41s/it]
#
#  83%|████████▎ | 43/52 [01:40<00:21,  2.41s/it]
#
#  85%|████████▍ | 44/52 [01:42<00:19,  2.43s/it]
#
#  87%|████████▋ | 45/52 [01:45<00:17,  2.43s/it]
#
#  88%|████████▊ | 46/52 [01:47<00:14,  2.44s/it]
#
#  90%|█████████ | 47/52 [01:49<00:12,  2.44s/it]
#
#  92%|█████████▏| 48/52 [01:52<00:09,  2.45s/it]
#
#  94%|█████████▍| 49/52 [01:54<00:07,  2.48s/it]
#
#  96%|█████████▌| 50/52 [01:57<00:05,  2.51s/it]
#
#  98%|█████████▊| 51/52 [02:00<00:02,  2.51s/it]
#
# 100%|██████████| 52/52 [02:02<00:00,  2.36s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:49,  2.14s/it]
#
#   4%|▍         | 2/52 [00:04<01:46,  2.13s/it]
#
#   6%|▌         | 3/52 [00:06<01:44,  2.13s/it]
#
#   8%|▊         | 4/52 [00:08<01:42,  2.14s/it]
#
#  10%|▉         | 5/52 [00:10<01:41,  2.15s/it]
#
#  12%|█▏        | 6/52 [00:12<01:39,  2.16s/it]
#
#  13%|█▎        | 7/52 [00:15<01:38,  2.18s/it]
#
#  15%|█▌        | 8/52 [00:17<01:35,  2.18s/it]
#
#  17%|█▋        | 9/52 [00:19<01:34,  2.19s/it]
#
#  19%|█▉        | 10/52 [00:21<01:31,  2.19s/it]
#
#  21%|██        | 11/52 [00:23<01:29,  2.19s/it]
#
#  23%|██▎       | 12/52 [00:26<01:28,  2.21s/it]
#
#  25%|██▌       | 13/52 [00:28<01:26,  2.21s/it]
#
#  27%|██▋       | 14/52 [00:30<01:24,  2.23s/it]
#
#  29%|██▉       | 15/52 [00:32<01:22,  2.24s/it]
#
#  31%|███       | 16/52 [00:35<01:21,  2.26s/it]
#
#  33%|███▎      | 17/52 [00:37<01:19,  2.27s/it]
#
#  35%|███▍      | 18/52 [00:39<01:17,  2.29s/it]
#
#  37%|███▋      | 19/52 [00:42<01:15,  2.29s/it]
#
#  38%|███▊      | 20/52 [00:44<01:13,  2.30s/it]
#
#  40%|████      | 21/52 [00:46<01:11,  2.30s/it]
#
#  42%|████▏     | 22/52 [00:49<01:09,  2.31s/it]
#
#  44%|████▍     | 23/52 [00:51<01:07,  2.31s/it]
#
#  46%|████▌     | 24/52 [00:53<01:04,  2.31s/it]
#
#  48%|████▊     | 25/52 [00:56<01:02,  2.32s/it]
#
#  50%|█████     | 26/52 [00:58<01:00,  2.33s/it]
#
#  52%|█████▏    | 27/52 [01:00<00:58,  2.33s/it]
#
#  54%|█████▍    | 28/52 [01:03<00:56,  2.34s/it]
#
#  56%|█████▌    | 29/52 [01:05<00:53,  2.34s/it]
#
#  58%|█████▊    | 30/52 [01:07<00:51,  2.36s/it]
#
#  60%|█████▉    | 31/52 [01:10<00:49,  2.36s/it]
#
#  62%|██████▏   | 32/52 [01:12<00:47,  2.38s/it]
#
#  63%|██████▎   | 33/52 [01:15<00:45,  2.42s/it]
#
#  65%|██████▌   | 34/52 [01:17<00:43,  2.42s/it]
#
#  67%|██████▋   | 35/52 [01:19<00:41,  2.42s/it]
#
#  69%|██████▉   | 36/52 [01:22<00:38,  2.41s/it]
#
#  71%|███████   | 37/52 [01:24<00:36,  2.43s/it]
#
#  73%|███████▎  | 38/52 [01:27<00:34,  2.43s/it]
#
#  75%|███████▌  | 39/52 [01:29<00:31,  2.44s/it]
#
#  77%|███████▋  | 40/52 [01:32<00:29,  2.44s/it]
#
#  79%|███████▉  | 41/52 [01:34<00:26,  2.45s/it]
#
#  81%|████████  | 42/52 [01:37<00:24,  2.45s/it]
#
#  83%|████████▎ | 43/52 [01:39<00:22,  2.46s/it]
#
#  85%|████████▍ | 44/52 [01:42<00:19,  2.47s/it]
#
#  87%|████████▋ | 45/52 [01:44<00:17,  2.48s/it]
#
#  88%|████████▊ | 46/52 [01:47<00:14,  2.49s/it]
#
#  90%|█████████ | 47/52 [01:49<00:12,  2.50s/it]
#
#  92%|█████████▏| 48/52 [01:52<00:10,  2.53s/it]
#
#  94%|█████████▍| 49/52 [01:54<00:07,  2.57s/it]
#
#  96%|█████████▌| 50/52 [01:57<00:05,  2.55s/it]
#
#  98%|█████████▊| 51/52 [01:59<00:02,  2.56s/it]
#
# 100%|██████████| 52/52 [02:02<00:00,  2.36s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:53,  2.23s/it]
#
#   4%|▍         | 2/52 [00:04<01:51,  2.23s/it]
#
#   6%|▌         | 3/52 [00:06<01:49,  2.23s/it]
#
#   8%|▊         | 4/52 [00:08<01:47,  2.24s/it]
#
#  10%|▉         | 5/52 [00:11<01:45,  2.24s/it]
#
#  12%|█▏        | 6/52 [00:13<01:44,  2.28s/it]
#
#  13%|█▎        | 7/52 [00:15<01:42,  2.29s/it]
#
#  15%|█▌        | 8/52 [00:18<01:40,  2.29s/it]
#
#  17%|█▋        | 9/52 [00:20<01:39,  2.31s/it]
#
#  19%|█▉        | 10/52 [00:22<01:37,  2.33s/it]
#
#  21%|██        | 11/52 [00:25<01:36,  2.34s/it]
#
#  23%|██▎       | 12/52 [00:27<01:34,  2.35s/it]
#
#  25%|██▌       | 13/52 [00:29<01:31,  2.35s/it]
#
#  27%|██▋       | 14/52 [00:32<01:29,  2.35s/it]
#
#  29%|██▉       | 15/52 [00:34<01:27,  2.35s/it]
#
#  31%|███       | 16/52 [00:37<01:25,  2.37s/it]
#
#  33%|███▎      | 17/52 [00:39<01:24,  2.42s/it]
#
#  35%|███▍      | 18/52 [00:42<01:23,  2.44s/it]
#
#  37%|███▋      | 19/52 [00:44<01:21,  2.48s/it]
#
#  38%|███▊      | 20/52 [00:47<01:20,  2.53s/it]
#
#  40%|████      | 21/52 [00:50<01:19,  2.57s/it]
#
#  42%|████▏     | 22/52 [00:52<01:17,  2.59s/it]
#
#  44%|████▍     | 23/52 [00:55<01:15,  2.61s/it]
#
#  46%|████▌     | 24/52 [00:58<01:14,  2.66s/it]
#
#  48%|████▊     | 25/52 [01:00<01:13,  2.71s/it]
#
#  50%|█████     | 26/52 [01:03<01:10,  2.71s/it]
#
#  52%|█████▏    | 27/52 [01:06<01:10,  2.83s/it]
#
#  54%|█████▍    | 28/52 [01:09<01:09,  2.88s/it]
#
#  56%|█████▌    | 29/52 [01:12<01:07,  2.95s/it]
#
#  58%|█████▊    | 30/52 [01:15<01:03,  2.91s/it]
#
#  60%|█████▉    | 31/52 [01:18<01:00,  2.89s/it]
#
#  62%|██████▏   | 32/52 [01:21<00:57,  2.87s/it]
#
#  63%|██████▎   | 33/52 [01:24<00:54,  2.87s/it]
#
#  65%|██████▌   | 34/52 [01:26<00:50,  2.83s/it]
#
#  67%|██████▋   | 35/52 [01:29<00:46,  2.76s/it]
#
#  69%|██████▉   | 36/52 [01:32<00:43,  2.73s/it]
#
#  71%|███████   | 37/52 [01:34<00:40,  2.70s/it]
#
#  73%|███████▎  | 38/52 [01:37<00:37,  2.69s/it]
#
#  75%|███████▌  | 39/52 [01:40<00:35,  2.71s/it]
#
#  77%|███████▋  | 40/52 [01:43<00:32,  2.73s/it]
#
#  79%|███████▉  | 41/52 [01:45<00:30,  2.75s/it]
#
#  81%|████████  | 42/52 [01:48<00:27,  2.78s/it]
#
#  83%|████████▎ | 43/52 [01:51<00:25,  2.82s/it]
#
#  85%|████████▍ | 44/52 [01:54<00:22,  2.81s/it]
#
#  87%|████████▋ | 45/52 [01:57<00:19,  2.77s/it]
#
#  88%|████████▊ | 46/52 [01:59<00:16,  2.78s/it]
#
#  90%|█████████ | 47/52 [02:02<00:13,  2.77s/it]
#
#  92%|█████████▏| 48/52 [02:05<00:11,  2.76s/it]
#
#  94%|█████████▍| 49/52 [02:08<00:08,  2.77s/it]
#
#  96%|█████████▌| 50/52 [02:10<00:05,  2.79s/it]
#
#  98%|█████████▊| 51/52 [02:13<00:02,  2.81s/it]
#
# 100%|██████████| 52/52 [02:16<00:00,  2.63s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:48,  2.14s/it]
#
#   4%|▍         | 2/52 [00:04<01:46,  2.12s/it]
#
#   6%|▌         | 3/52 [00:06<01:43,  2.12s/it]
#
#   8%|▊         | 4/52 [00:08<01:42,  2.13s/it]
#
#  10%|▉         | 5/52 [00:10<01:39,  2.12s/it]
#
#  12%|█▏        | 6/52 [00:12<01:37,  2.13s/it]
#
#  13%|█▎        | 7/52 [00:14<01:36,  2.14s/it]
#
#  15%|█▌        | 8/52 [00:17<01:33,  2.13s/it]
#
#  17%|█▋        | 9/52 [00:19<01:31,  2.13s/it]
#
#  19%|█▉        | 10/52 [00:21<01:29,  2.14s/it]
#
#  21%|██        | 11/52 [00:23<01:28,  2.15s/it]
#
#  23%|██▎       | 12/52 [00:25<01:25,  2.15s/it]
#
#  25%|██▌       | 13/52 [00:27<01:24,  2.16s/it]
#
#  27%|██▋       | 14/52 [00:29<01:21,  2.16s/it]
#
#  29%|██▉       | 15/52 [00:32<01:19,  2.16s/it]
#
#  31%|███       | 16/52 [00:34<01:18,  2.17s/it]
#
#  33%|███▎      | 17/52 [00:36<01:16,  2.18s/it]
#
#  35%|███▍      | 18/52 [00:38<01:14,  2.20s/it]
#
#  37%|███▋      | 19/52 [00:40<01:12,  2.20s/it]
#
#  38%|███▊      | 20/52 [00:43<01:10,  2.21s/it]
#
#  40%|████      | 21/52 [00:45<01:08,  2.22s/it]
#
#  42%|████▏     | 22/52 [00:47<01:06,  2.23s/it]
#
#  44%|████▍     | 23/52 [00:49<01:04,  2.23s/it]
#
#  46%|████▌     | 24/52 [00:52<01:02,  2.24s/it]
#
#  48%|████▊     | 25/52 [00:54<01:00,  2.26s/it]
#
#  50%|█████     | 26/52 [00:56<00:59,  2.28s/it]
#
#  52%|█████▏    | 27/52 [00:59<00:57,  2.29s/it]
#
#  54%|█████▍    | 28/52 [01:01<00:55,  2.30s/it]
#
#  56%|█████▌    | 29/52 [01:03<00:52,  2.30s/it]
#
#  58%|█████▊    | 30/52 [01:06<00:50,  2.31s/it]
#
#  60%|█████▉    | 31/52 [01:08<00:48,  2.31s/it]
#
#  62%|██████▏   | 32/52 [01:10<00:46,  2.33s/it]
#
#  63%|██████▎   | 33/52 [01:13<00:44,  2.33s/it]
#
#  65%|██████▌   | 34/52 [01:15<00:42,  2.34s/it]
#
#  67%|██████▋   | 35/52 [01:17<00:39,  2.34s/it]
#
#  69%|██████▉   | 36/52 [01:20<00:37,  2.34s/it]
#
#  71%|███████   | 37/52 [01:22<00:35,  2.35s/it]
#
#  73%|███████▎  | 38/52 [01:24<00:33,  2.36s/it]
#
#  75%|███████▌  | 39/52 [01:27<00:30,  2.38s/it]
#
#  77%|███████▋  | 40/52 [01:29<00:28,  2.37s/it]
#
#  79%|███████▉  | 41/52 [01:32<00:26,  2.38s/it]
#
#  81%|████████  | 42/52 [01:34<00:24,  2.41s/it]
#
#  83%|████████▎ | 43/52 [01:36<00:21,  2.41s/it]
#
#  85%|████████▍ | 44/52 [01:39<00:19,  2.41s/it]
#
#  87%|████████▋ | 45/52 [01:41<00:16,  2.42s/it]
#
#  88%|████████▊ | 46/52 [01:44<00:14,  2.43s/it]
#
#  90%|█████████ | 47/52 [01:46<00:12,  2.46s/it]
#
#  92%|█████████▏| 48/52 [01:49<00:09,  2.48s/it]
#
#  94%|█████████▍| 49/52 [01:52<00:07,  2.54s/it]
#
#  96%|█████████▌| 50/52 [01:54<00:05,  2.59s/it]
#
#  98%|█████████▊| 51/52 [01:57<00:02,  2.63s/it]
#
# 100%|██████████| 52/52 [02:00<00:00,  2.31s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<02:07,  2.51s/it]
#
#   4%|▍         | 2/52 [00:04<02:04,  2.49s/it]
#
#   6%|▌         | 3/52 [00:07<02:02,  2.49s/it]
#
#   8%|▊         | 4/52 [00:09<01:59,  2.49s/it]
#
#  10%|▉         | 5/52 [00:12<01:57,  2.50s/it]
#
#  12%|█▏        | 6/52 [00:14<01:55,  2.50s/it]
#
#  13%|█▎        | 7/52 [00:17<01:52,  2.51s/it]
#
#  15%|█▌        | 8/52 [00:20<01:50,  2.51s/it]
#
#  17%|█▋        | 9/52 [00:22<01:49,  2.54s/it]
#
#  19%|█▉        | 10/52 [00:25<01:46,  2.54s/it]
#
#  21%|██        | 11/52 [00:27<01:44,  2.55s/it]
#
#  23%|██▎       | 12/52 [00:30<01:49,  2.75s/it]
#
#  25%|██▌       | 13/52 [00:34<01:51,  2.85s/it]
#
#  27%|██▋       | 14/52 [00:36<01:45,  2.77s/it]
#
#  29%|██▉       | 15/52 [00:39<01:41,  2.74s/it]
#
#  31%|███       | 16/52 [00:41<01:37,  2.70s/it]
#
#  33%|███▎      | 17/52 [00:44<01:34,  2.69s/it]
#
#  35%|███▍      | 18/52 [00:47<01:31,  2.69s/it]
#
#  37%|███▋      | 19/52 [00:49<01:28,  2.67s/it]
#
#  38%|███▊      | 20/52 [00:52<01:25,  2.68s/it]
#
#  40%|████      | 21/52 [00:55<01:24,  2.74s/it]
#
#  42%|████▏     | 22/52 [00:58<01:22,  2.75s/it]
#
#  44%|████▍     | 23/52 [01:01<01:20,  2.77s/it]
#
#  46%|████▌     | 24/52 [01:03<01:17,  2.78s/it]
#
#  48%|████▊     | 25/52 [01:06<01:15,  2.78s/it]
#
#  50%|█████     | 26/52 [01:09<01:11,  2.76s/it]
#
#  52%|█████▏    | 27/52 [01:12<01:08,  2.76s/it]
#
#  54%|█████▍    | 28/52 [01:14<01:05,  2.74s/it]
#
#  56%|█████▌    | 29/52 [01:17<01:02,  2.71s/it]
#
#  58%|█████▊    | 30/52 [01:20<00:59,  2.69s/it]
#
#  60%|█████▉    | 31/52 [01:22<00:56,  2.67s/it]
#
#  62%|██████▏   | 32/52 [01:25<00:53,  2.70s/it]
#
#  63%|██████▎   | 33/52 [01:28<00:50,  2.68s/it]
#
#  65%|██████▌   | 34/52 [01:30<00:48,  2.68s/it]
#
#  67%|██████▋   | 35/52 [01:33<00:45,  2.70s/it]
#
#  69%|██████▉   | 36/52 [01:36<00:43,  2.72s/it]
#
#  71%|███████   | 37/52 [01:39<00:40,  2.71s/it]
#
#  73%|███████▎  | 38/52 [01:41<00:38,  2.74s/it]
#
#  75%|███████▌  | 39/52 [01:44<00:35,  2.72s/it]
#
#  77%|███████▋  | 40/52 [01:47<00:32,  2.74s/it]
#
#  79%|███████▉  | 41/52 [01:50<00:30,  2.75s/it]
#
#  81%|████████  | 42/52 [01:52<00:27,  2.74s/it]
#
#  83%|████████▎ | 43/52 [01:55<00:24,  2.76s/it]
#
#  85%|████████▍ | 44/52 [01:58<00:22,  2.78s/it]
#
#  87%|████████▋ | 45/52 [02:01<00:19,  2.81s/it]
#
#  88%|████████▊ | 46/52 [02:04<00:16,  2.83s/it]
#
#  90%|█████████ | 47/52 [02:07<00:14,  2.85s/it]
#
#  92%|█████████▏| 48/52 [02:10<00:11,  2.89s/it]
#
#  94%|█████████▍| 49/52 [02:12<00:08,  2.91s/it]
#
#  96%|█████████▌| 50/52 [02:15<00:05,  2.91s/it]
#
#  98%|█████████▊| 51/52 [02:18<00:02,  2.94s/it]
#
# 100%|██████████| 52/52 [02:21<00:00,  2.73s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:52,  2.20s/it]
#
#   4%|▍         | 2/52 [00:04<01:50,  2.21s/it]
#
#   6%|▌         | 3/52 [00:06<01:48,  2.21s/it]
#
#   8%|▊         | 4/52 [00:08<01:46,  2.22s/it]
#
#  10%|▉         | 5/52 [00:11<01:44,  2.23s/it]
#
#  12%|█▏        | 6/52 [00:13<01:42,  2.24s/it]
#
#  13%|█▎        | 7/52 [00:15<01:41,  2.26s/it]
#
#  15%|█▌        | 8/52 [00:17<01:39,  2.27s/it]
#
#  17%|█▋        | 9/52 [00:20<01:36,  2.25s/it]
#
#  19%|█▉        | 10/52 [00:22<01:34,  2.26s/it]
#
#  21%|██        | 11/52 [00:24<01:32,  2.25s/it]
#
#  23%|██▎       | 12/52 [00:26<01:30,  2.25s/it]
#
#  25%|██▌       | 13/52 [00:29<01:28,  2.28s/it]
#
#  27%|██▋       | 14/52 [00:31<01:26,  2.28s/it]
#
#  29%|██▉       | 15/52 [00:33<01:25,  2.30s/it]
#
#  31%|███       | 16/52 [00:36<01:23,  2.31s/it]
#
#  33%|███▎      | 17/52 [00:38<01:21,  2.33s/it]
#
#  35%|███▍      | 18/52 [00:41<01:19,  2.35s/it]
#
#  37%|███▋      | 19/52 [00:43<01:18,  2.37s/it]
#
#  38%|███▊      | 20/52 [00:45<01:15,  2.36s/it]
#
#  40%|████      | 21/52 [00:48<01:12,  2.34s/it]
#
#  42%|████▏     | 22/52 [00:50<01:09,  2.32s/it]
#
#  44%|████▍     | 23/52 [00:52<01:07,  2.31s/it]
#
#  46%|████▌     | 24/52 [00:55<01:05,  2.34s/it]
#
#  48%|████▊     | 25/52 [00:57<01:03,  2.37s/it]
#
#  50%|█████     | 26/52 [00:59<01:01,  2.38s/it]
#
#  52%|█████▏    | 27/52 [01:02<00:59,  2.38s/it]
#
#  54%|█████▍    | 28/52 [01:04<00:57,  2.38s/it]
#
#  56%|█████▌    | 29/52 [01:07<00:54,  2.39s/it]
#
#  58%|█████▊    | 30/52 [01:09<00:52,  2.39s/it]
#
#  60%|█████▉    | 31/52 [01:11<00:50,  2.42s/it]
#
#  62%|██████▏   | 32/52 [01:14<00:48,  2.43s/it]
#  63%|██████▎   | 33/52 [01:16<00:46,  2.43s/it]
#
#  65%|██████▌   | 34/52 [01:19<00:43,  2.43s/it]
#
#  67%|██████▋   | 35/52 [01:21<00:41,  2.42s/it]
#
#  69%|██████▉   | 36/52 [01:24<00:38,  2.43s/it]
#
#  71%|███████   | 37/52 [01:26<00:36,  2.42s/it]
#
#  73%|███████▎  | 38/52 [01:28<00:33,  2.43s/it]
#
#  75%|███████▌  | 39/52 [01:31<00:31,  2.44s/it]
#
#  77%|███████▋  | 40/52 [01:33<00:29,  2.45s/it]
#
#  79%|███████▉  | 41/52 [01:36<00:27,  2.46s/it]
#
#  81%|████████  | 42/52 [01:38<00:24,  2.48s/it]
#
#  83%|████████▎ | 43/52 [01:41<00:22,  2.48s/it]
#
#  85%|████████▍ | 44/52 [01:43<00:19,  2.49s/it]
#
#  87%|████████▋ | 45/52 [01:46<00:17,  2.49s/it]
#
#  88%|████████▊ | 46/52 [01:48<00:15,  2.50s/it]
#
#  90%|█████████ | 47/52 [01:51<00:12,  2.51s/it]
#
#  92%|█████████▏| 48/52 [01:54<00:10,  2.52s/it]
#
#  94%|█████████▍| 49/52 [01:56<00:07,  2.52s/it]
#
#  96%|█████████▌| 50/52 [01:59<00:05,  2.54s/it]
#
#  98%|█████████▊| 51/52 [02:01<00:02,  2.55s/it]
#
# 100%|██████████| 52/52 [02:04<00:00,  2.39s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:50,  2.17s/it]
#
#   4%|▍         | 2/52 [00:04<01:49,  2.18s/it]
#
#   6%|▌         | 3/52 [00:06<01:45,  2.16s/it]
#
#   8%|▊         | 4/52 [00:08<01:43,  2.15s/it]
#
#  10%|▉         | 5/52 [00:10<01:41,  2.15s/it]
#
#  12%|█▏        | 6/52 [00:12<01:39,  2.16s/it]
#
#  13%|█▎        | 7/52 [00:15<01:37,  2.16s/it]
#
#  15%|█▌        | 8/52 [00:17<01:35,  2.17s/it]
#
#  17%|█▋        | 9/52 [00:19<01:33,  2.18s/it]
#
#  19%|█▉        | 10/52 [00:21<01:31,  2.19s/it]
#
#  21%|██        | 11/52 [00:23<01:30,  2.20s/it]
#
#  23%|██▎       | 12/52 [00:26<01:28,  2.21s/it]
#
#  25%|██▌       | 13/52 [00:28<01:26,  2.21s/it]
#
#  27%|██▋       | 14/52 [00:30<01:24,  2.22s/it]
#
#  29%|██▉       | 15/52 [00:32<01:23,  2.26s/it]
#
#  31%|███       | 16/52 [00:35<01:21,  2.25s/it]
#
#  33%|███▎      | 17/52 [00:37<01:19,  2.26s/it]
#
#  35%|███▍      | 18/52 [00:39<01:18,  2.30s/it]
#
#  37%|███▋      | 19/52 [00:42<01:16,  2.31s/it]
#
#  38%|███▊      | 20/52 [00:44<01:13,  2.30s/it]
#
#  40%|████      | 21/52 [00:46<01:11,  2.30s/it]
#
#  42%|████▏     | 22/52 [00:49<01:08,  2.30s/it]
#
#  44%|████▍     | 23/52 [00:51<01:06,  2.31s/it]
#
#  46%|████▌     | 24/52 [00:53<01:04,  2.32s/it]
#
#  48%|████▊     | 25/52 [00:56<01:02,  2.33s/it]
#
#  50%|█████     | 26/52 [00:58<01:00,  2.34s/it]
#
#  52%|█████▏    | 27/52 [01:00<00:58,  2.33s/it]
#
#  54%|█████▍    | 28/52 [01:03<00:55,  2.33s/it]
#
#  56%|█████▌    | 29/52 [01:05<00:53,  2.33s/it]
#
#  58%|█████▊    | 30/52 [01:07<00:51,  2.36s/it]
#
#  60%|█████▉    | 31/52 [01:10<00:49,  2.37s/it]
#
#  62%|██████▏   | 32/52 [01:12<00:47,  2.37s/it]
#
#  63%|██████▎   | 33/52 [01:15<00:45,  2.37s/it]
#
#  65%|██████▌   | 34/52 [01:17<00:42,  2.37s/it]
#
#  67%|██████▋   | 35/52 [01:19<00:40,  2.38s/it]
#
#  69%|██████▉   | 36/52 [01:22<00:38,  2.39s/it]
#
#  71%|███████   | 37/52 [01:24<00:36,  2.41s/it]
#
#  73%|███████▎  | 38/52 [01:27<00:33,  2.41s/it]
#
#  75%|███████▌  | 39/52 [01:29<00:31,  2.43s/it]
#
#  77%|███████▋  | 40/52 [01:32<00:29,  2.45s/it]
#
#  79%|███████▉  | 41/52 [01:34<00:26,  2.44s/it]
#
#  81%|████████  | 42/52 [01:36<00:24,  2.45s/it]
#
#  83%|████████▎ | 43/52 [01:39<00:22,  2.46s/it]
#
#  85%|████████▍ | 44/52 [01:41<00:19,  2.46s/it]
#
#  87%|████████▋ | 45/52 [01:44<00:17,  2.48s/it]
#
#  88%|████████▊ | 46/52 [01:46<00:14,  2.48s/it]
#
#  90%|█████████ | 47/52 [01:49<00:12,  2.50s/it]
#
#  92%|█████████▏| 48/52 [01:51<00:10,  2.50s/it]
#
#  94%|█████████▍| 49/52 [01:54<00:07,  2.51s/it]
#
#  96%|█████████▌| 50/52 [01:57<00:05,  2.52s/it]
#
#  98%|█████████▊| 51/52 [01:59<00:02,  2.53s/it]
#
# 100%|██████████| 52/52 [02:02<00:00,  2.35s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:01<01:40,  1.98s/it]
#
#   4%|▍         | 2/52 [00:03<01:39,  1.98s/it]
#
#   6%|▌         | 3/52 [00:05<01:37,  1.99s/it]
#
#   8%|▊         | 4/52 [00:07<01:35,  2.00s/it]
#
#  10%|▉         | 5/52 [00:10<01:34,  2.00s/it]
#
#  12%|█▏        | 6/52 [00:12<01:32,  2.01s/it]
#
#  13%|█▎        | 7/52 [00:14<01:30,  2.02s/it]
#
#  15%|█▌        | 8/52 [00:16<01:29,  2.03s/it]
#
#  17%|█▋        | 9/52 [00:18<01:27,  2.04s/it]
#
#  19%|█▉        | 10/52 [00:20<01:25,  2.04s/it]
#
#  21%|██        | 11/52 [00:22<01:24,  2.06s/it]
#
#  23%|██▎       | 12/52 [00:24<01:22,  2.07s/it]
#
#  25%|██▌       | 13/52 [00:26<01:20,  2.07s/it]
#
#  27%|██▋       | 14/52 [00:28<01:18,  2.08s/it]
#
#  29%|██▉       | 15/52 [00:30<01:18,  2.11s/it]
#
#  31%|███       | 16/52 [00:32<01:16,  2.12s/it]
#
#  33%|███▎      | 17/52 [00:35<01:14,  2.12s/it]
#
#  35%|███▍      | 18/52 [00:37<01:12,  2.13s/it]
#
#  37%|███▋      | 19/52 [00:39<01:10,  2.13s/it]
#
#  38%|███▊      | 20/52 [00:41<01:08,  2.14s/it]
#
#  40%|████      | 21/52 [00:43<01:06,  2.15s/it]
#
#  42%|████▏     | 22/52 [00:45<01:04,  2.16s/it]
#
#  44%|████▍     | 23/52 [00:48<01:02,  2.17s/it]
#
#  46%|████▌     | 24/52 [00:50<01:00,  2.17s/it]
#
#  48%|████▊     | 25/52 [00:52<00:58,  2.18s/it]
#
#  50%|█████     | 26/52 [00:54<00:56,  2.19s/it]
#
#  52%|█████▏    | 27/52 [00:56<00:54,  2.19s/it]
#
#  54%|█████▍    | 28/52 [00:59<00:52,  2.21s/it]
#
#  56%|█████▌    | 29/52 [01:01<00:50,  2.20s/it]
#
#  58%|█████▊    | 30/52 [01:03<00:48,  2.22s/it]
#
#  60%|█████▉    | 31/52 [01:05<00:47,  2.24s/it]
#
#  62%|██████▏   | 32/52 [01:08<00:45,  2.26s/it]
#
#  63%|██████▎   | 33/52 [01:10<00:42,  2.26s/it]
#
#  65%|██████▌   | 34/52 [01:12<00:40,  2.26s/it]
#
#  67%|██████▋   | 35/52 [01:14<00:38,  2.26s/it]
#
#  69%|██████▉   | 36/52 [01:17<00:36,  2.27s/it]
#
#  71%|███████   | 37/52 [01:19<00:34,  2.27s/it]
#
#  73%|███████▎  | 38/52 [01:21<00:31,  2.28s/it]
#
#  75%|███████▌  | 39/52 [01:24<00:29,  2.28s/it]
#
#  77%|███████▋  | 40/52 [01:26<00:27,  2.29s/it]
#
#  79%|███████▉  | 41/52 [01:28<00:25,  2.30s/it]
#
#  81%|████████  | 42/52 [01:31<00:23,  2.33s/it]
#
#  83%|████████▎ | 43/52 [01:33<00:21,  2.34s/it]
#
#  85%|████████▍ | 44/52 [01:35<00:18,  2.35s/it]
#
#  87%|████████▋ | 45/52 [01:38<00:16,  2.36s/it]
#
#  88%|████████▊ | 46/52 [01:40<00:14,  2.36s/it]
#
#  90%|█████████ | 47/52 [01:42<00:11,  2.36s/it]
#
#  92%|█████████▏| 48/52 [01:45<00:09,  2.37s/it]
#
#  94%|█████████▍| 49/52 [01:47<00:07,  2.38s/it]
#
#  96%|█████████▌| 50/52 [01:50<00:04,  2.39s/it]
#
#  98%|█████████▊| 51/52 [01:52<00:02,  2.40s/it]
#
# 100%|██████████| 52/52 [01:54<00:00,  2.21s/it]
#
#
#   0%|          | 0/52 [00:00<?, ?it/s]
#
#   2%|▏         | 1/52 [00:02<01:46,  2.08s/it]
#
#   4%|▍         | 2/52 [00:04<01:44,  2.09s/it]
#
#   6%|▌         | 3/52 [00:06<01:44,  2.13s/it]
#
#   8%|▊         | 4/52 [00:08<01:42,  2.13s/it]
#
#  10%|▉         | 5/52 [00:10<01:39,  2.12s/it]
#
#  12%|█▏        | 6/52 [00:12<01:37,  2.13s/it]
#
#  13%|█▎        | 7/52 [00:14<01:35,  2.13s/it]
#
#  15%|█▌        | 8/52 [00:17<01:33,  2.13s/it]
#
#  17%|█▋        | 9/52 [00:19<01:32,  2.14s/it]
#
#  19%|█▉        | 10/52 [00:21<01:30,  2.16s/it]
#
#  21%|██        | 11/52 [00:23<01:29,  2.17s/it]
#
#  23%|██▎       | 12/52 [00:25<01:27,  2.18s/it]
#
#  25%|██▌       | 13/52 [00:28<01:25,  2.19s/it]
#
#  27%|██▋       | 14/52 [00:30<01:23,  2.21s/it]
#
#  29%|██▉       | 15/52 [00:32<01:23,  2.25s/it]
#
#  31%|███       | 16/52 [00:35<01:22,  2.29s/it]
#
#  33%|███▎      | 17/52 [00:37<01:21,  2.32s/it]
#
#  35%|███▍      | 18/52 [00:39<01:19,  2.33s/it]
#
#  37%|███▋      | 19/52 [00:42<01:17,  2.34s/it]
#
#  38%|███▊      | 20/52 [00:44<01:15,  2.35s/it]
#
#  40%|████      | 21/52 [00:46<01:13,  2.39s/it]
#
#  42%|████▏     | 22/52 [00:49<01:11,  2.40s/it]
#
#  44%|████▍     | 23/52 [00:51<01:09,  2.40s/it]
#
#  46%|████▌     | 24/52 [00:54<01:07,  2.40s/it]
#
#  48%|████▊     | 25/52 [00:56<01:04,  2.39s/it]
#
#  50%|█████     | 26/52 [00:59<01:02,  2.42s/it]
#
#  52%|█████▏    | 27/52 [01:01<01:00,  2.43s/it]
#
#  54%|█████▍    | 28/52 [01:03<00:58,  2.44s/it]
#
#  56%|█████▌    | 29/52 [01:06<00:56,  2.44s/it]
#
#  58%|█████▊    | 30/52 [01:08<00:53,  2.44s/it]
#
#  60%|█████▉    | 31/52 [01:11<00:52,  2.49s/it]
#
#  62%|██████▏   | 32/52 [01:14<00:50,  2.52s/it]
#
#  63%|██████▎   | 33/52 [01:16<00:47,  2.51s/it]
#
#  65%|██████▌   | 34/52 [01:19<00:45,  2.55s/it]
#
#  67%|██████▋   | 35/52 [01:21<00:42,  2.53s/it]
#
#  69%|██████▉   | 36/52 [01:24<00:40,  2.52s/it]
#
#  71%|███████   | 37/52 [01:26<00:38,  2.54s/it]
#
#  73%|███████▎  | 38/52 [01:29<00:35,  2.55s/it]
#
#  75%|███████▌  | 39/52 [01:31<00:33,  2.54s/it]
#
#  77%|███████▋  | 40/52 [01:34<00:30,  2.57s/it]
#
#  79%|███████▉  | 41/52 [01:37<00:28,  2.61s/it]
#
#  81%|████████  | 42/52 [01:39<00:26,  2.62s/it]
#
#  83%|████████▎ | 43/52 [01:42<00:23,  2.60s/it]
#
#  85%|████████▍ | 44/52 [01:44<00:20,  2.59s/it]
#
#  87%|████████▋ | 45/52 [01:47<00:18,  2.59s/it]
#
#  88%|████████▊ | 46/52 [01:50<00:15,  2.60s/it]
#
#  90%|█████████ | 47/52 [01:52<00:13,  2.60s/it]
#
#  92%|█████████▏| 48/52 [01:55<00:10,  2.61s/it]
#
#  94%|█████████▍| 49/52 [01:58<00:07,  2.62s/it]
#
#  96%|█████████▌| 50/52 [02:00<00:05,  2.65s/it]
#
#  98%|█████████▊| 51/52 [02:03<00:02,  2.64s/it]
#
# 100%|██████████| 52/52 [02:05<00:00,  2.42s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-238-ecf5e05839e3> in <module>
#      24     dist = list(districts)[i]
#      25     temp_pred = [np.nan] + y_pred[i]
# ---> 26     MSE = mean_squared_error(y_true[11:], temp_pred[11:])
#      27     MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
#      28     prediction[dist] = {'MSE': MSE, 'MAE': MAE}
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [325, 326]

# %%
# y = []
# prediction = {}
# for i in range(len(temp_df)):
#     y_true = np.array(temp_df[i][1].tolist())
#     y_predicted = np.array(y_pred[i])
#     temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
#     y.append(temp)
    
#     dist = list(districts)[i]
#     temp_pred = [np.nan] + y_pred[i]
#     MSE = mean_squared_error(y_true[284:], temp_pred[285:])
#     MAE = mean_absolute_error(y_true[284:], temp_pred[285:])
#     prediction[dist] = {'MSE': MSE, 'MAE': MAE}
#     print ('Mean Squared Error for district %s = %s'%(dist, MSE))
#     print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

# #### Finding average of MSE and MAE

# total_MSE = 0
# total_MAE = 0
# for i in prediction:
#     total_MSE += prediction[i]['MSE']
#     total_MAE += prediction[i]['MAE']
    
# avg_MSE = total_MSE/len(districts)
# avg_MAE = total_MAE/len(districts)

# print ('Average of Mean Squared Error = %s'%avg_MSE)
# print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# Mean Squared Error for district NORTHEAST = 362.1954096153847
# Mean Absolute Error for district NORTHEAST = 14.933653846153847
#
#
# Mean Squared Error for district SOUTHERN = 224.7304942307692
# Mean Absolute Error for district SOUTHERN = 12.045192307692306
#
#
# Mean Squared Error for district EASTERN = 196.44110192307693
# Mean Absolute Error for district EASTERN = 10.85980769230769
#
#
# Mean Squared Error for district CENTRAL = 306.0618865384615
# Mean Absolute Error for district CENTRAL = 14.351730769230768
#
#
# Mean Squared Error for district WESTERN = 190.25191346153846
# Mean Absolute Error for district WESTERN = 11.9475
#
#
# Mean Squared Error for district SOUTHEAST = 357.69363653846153
# Mean Absolute Error for district SOUTHEAST = 14.739423076923076
#
#
# Mean Squared Error for district NORTHERN = 289.10678461538464
# Mean Absolute Error for district NORTHERN = 13.880384615384616
#
#
# Mean Squared Error for district SOUTHWEST = 211.75966153846156
# Mean Absolute Error for district SOUTHWEST = 11.531153846153845
#
#
# Mean Squared Error for district NORTHWEST = 353.54020576923074
# Mean Absolute Error for district NORTHWEST = 12.387500000000001
#
#
# Average of Mean Squared Error = 276.864566025641
# Average of Mean Absolute Error = 12.964038461538461

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Predicted_Crime_Vs_True_Crime_RFR.jpg')

# %% [markdown]
# #### Traing Multilayer Perceptron regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 310   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    MLPR = MLPRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        MLPR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = MLPR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of multilayer perceptron regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)

# %% [markdown]
# #### MLPR prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Predicted_Crime_Vs_True_Crime_MLPRegressor.jpg')

# %% [markdown]
# #### Traing support vector regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 310   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    SVRegr = SVR()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        SVRegr.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = SVRegr.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of support vector regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))
    
#### Finding average of MSE and MAE
    
total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)

# %% [markdown]
# #### SVR visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Predicted_Crime_Vs_True_Crime_SVR.jpg')
