# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
crime_type = input('Enter Crime Type: ')
# Out:
# Enter Crime Type: Homicide

# %%
if not os.path.exists('../../Graphs/With_Census/Sub_Crime/%s'%crime_type):
    os.makedirs('../../Graphs/With_Census/Sub_Crime/%s'%crime_type)

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../../Clean Dataset/Sub Crimes By Neighborhood/Preprocessed_data/Preprocessed_%s_data.csv'%crime_type)
data.head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      SOUTHEAST            1           2014_1           0
# 1  2014      SOUTHEAST            2           2014_2           0
# 2  2014      SOUTHEAST            3           2014_3           0
# 3  2014      SOUTHEAST            4           2014_4           0
# 4  2014      SOUTHEAST            5           2014_5           2

# %%
data.describe()
# Out:
#               Year  Week_Number   NoOfCrimes
# count  3024.000000  3024.000000  3024.000000
# mean   2016.735119    25.586310     0.635251
# std       1.870681    15.096201     0.855154
# min    2014.000000     1.000000     0.000000
# 25%    2015.000000    12.750000     0.000000
# 50%    2017.000000    25.000000     0.000000
# 75%    2018.000000    39.000000     1.000000
# max    2020.000000    53.000000     5.000000

# %%
PoliceDistrict = data['PoliceDistrict'].unique()
ts_data_week = {}
for district in PoliceDistrict:
    ts_data_week[district] = data[data['PoliceDistrict'] == district]

# %% [markdown]
# ## Importing Population Dataset

# %%
population_data = pd.read_csv('../../Clean Dataset/Population_By_PoliceDistrict.csv')
population_data
# Out:
#   Police District  Population
# 0         CENTRAL       34300
# 1        NORTHERN       95194
# 2       NORTHWEST       78736
# 3         WESTERN       39691
# 4         EASTERN       42653
# 5       NORTHEAST      155040
# 6       SOUTHEAST       69535
# 7        SOUTHERN       60141
# 8       SOUTHWEST       68743

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()
# Out:
#       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 2016  2014      NORTHEAST            1           2014_1           1
# 2017  2014      NORTHEAST            2           2014_2           2
# 2018  2014      NORTHEAST            3           2014_3           0
# 2019  2014      NORTHEAST            4           2014_4           1
# 2020  2014      NORTHEAST            5           2014_5           0

# %%
df = pd.DataFrame()

for i in PoliceDistrict:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year 2019', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../../Graphs/With_Census/Sub_Crime/%s/policeDistrictCrimes.jpg'%crime_type)
plt.show()

# %%
fig = plt.figure()
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/With_Census/Sub_Crime/%s/True_Crime_Baltimre.jpg'%crime_type)

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
df_shift = pd.DataFrame()
temp_df = []
for district in PoliceDistrict:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.93it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.43it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.25it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.07it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.25it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.27it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.76it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.11it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (335, 754)
# (335, 337)
# (335, 754)
# (335, 348)
# (335, 754)
# (335, 344)
# (335, 754)
# (335, 340)
# (335, 754)
# (335, 342)
# (335, 754)
# (335, 348)
# (335, 754)
# (335, 347)
# (335, 754)
# (335, 346)
# (335, 754)
# (335, 330)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ### Appending Population to time series features

# %%
districts = data['PoliceDistrict'].unique()
i = 0
for district in districts:
    population = population_data[population_data['Police District'] == district]['Population'].values[0]
    ts_features[i][0]['Population'] = [population] * ts_features[i][0].shape[0]

# %%
ts_features[i][0]
# Out:
# variable  value__abs_energy  value__absolute_sum_of_changes  \
# id
# 2                       0.0                             0.0
# 3                       0.0                             0.0
# 4                       0.0                             0.0
# 5                       4.0                             2.0
# 6                       4.0                             4.0
# ..                      ...                             ...
# 331                    17.0                            13.0
# 332                     8.0                            11.0
# 333                     7.0                            10.0
# 334                     8.0                            10.0
# 335                     8.0                            10.0
#
# variable  value__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# id
# 2                                                  0.000000
# 3                                                  0.000000
# 4                                                  0.000000
# 5                                                 -0.401042
# 6                                                 -0.156000
# ..                                                      ...
# 331                                               -0.287061
# 332                                               -0.161034
# 333                                               -0.092024
# 334                                               -0.028697
# 335                                                0.035949
#
# variable  value__agg_autocorrelation__f_agg_"median"__maxlag_40  \
# id
# 2                                                  0.000000
# 3                                                  0.000000
# 4                                                  0.000000
# 5                                                 -0.270833
# 6                                                 -0.200000
# ..                                                      ...
# 331                                               -0.187215
# 332                                               -0.166667
# 333                                               -0.084249
# 334                                               -0.062500
# 335                                               -0.122807
#
# variable  value__agg_autocorrelation__f_agg_"var"__maxlag_40  \
# id
# 2                                                  0.000000
# 3                                                  0.000000
# 4                                                  0.000000
# 5                                                  0.132243
# 6                                                  0.041344
# ..                                                      ...
# 331                                                0.475673
# 332                                                0.153861
# 333                                                0.131873
# 334                                                0.275882
# 335                                                0.224281
#
# variable  value__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# 2                                                       1.0
# 3                                                       1.0
# 4                                                       1.0
# 5                                                       1.0
# 6                                                       1.0
# ..                                                      ...
# 331                                                     3.0
# 332                                                     1.0
# 333                                                     1.0
# 334                                                     1.0
# 335                                                     1.0
#
# variable  value__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"  \
# id
# 2                                                       0.0
# 3                                                       0.0
# 4                                                       0.0
# 5                                                       0.0
# 6                                                       0.0
# ..                                                      ...
# 331                                                    -1.0
# 332                                                     0.0
# 333                                                     0.0
# 334                                                     0.0
# 335                                                     0.0
#
# variable  value__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"  \
# id
# 2                                                       0.0
# 3                                                       0.0
# 4                                                       0.0
# 5                                                       0.0
# 6                                                       0.0
# ..                                                      ...
# 331                                                    -2.0
# 332                                                     0.0
# 333                                                     0.0
# 334                                                     0.0
# 335                                                     0.0
#
# variable  value__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"  \
# id
# 2                                                       1.0
# 3                                                       1.0
# 4                                                       1.0
# 5                                                       1.0
# 6                                                       2.0
# ..                                                      ...
# 331                                                     2.4
# 332                                                     1.0
# 333                                                     1.2
# 334                                                     1.0
# 335                                                     1.0
#
# variable  value__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"  \
# id
# 2                                                  0.000000
# 3                                                  0.000000
# 4                                                  0.000000
# 5                                                  0.000000
# 6                                                 -1.000000
# ..                                                      ...
# 331                                               -0.774597
# 332                                                0.000000
# 333                                               -0.774597
# 334                                                0.000000
# 335                                                0.000000
#
# variable  ...  value__symmetry_looking__r_0.9  \
# id        ...
# 2         ...                             0.0
# 3         ...                             0.0
# 4         ...                             0.0
# 5         ...                             1.0
# 6         ...                             1.0
# ..        ...                             ...
# 331       ...                             1.0
# 332       ...                             1.0
# 333       ...                             1.0
# 334       ...                             1.0
# 335       ...                             1.0
#
# variable  value__symmetry_looking__r_0.9500000000000001  \
# id
# 2                                                   0.0
# 3                                                   0.0
# 4                                                   0.0
# 5                                                   1.0
# 6                                                   1.0
# ..                                                  ...
# 331                                                 1.0
# 332                                                 1.0
# 333                                                 1.0
# 334                                                 1.0
# 335                                                 1.0
#
# variable  value__time_reversal_asymmetry_statistic__lag_1  \
# id
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 6                                                0.000000
# ..                                                    ...
# 331                                             -0.500000
# 332                                              0.000000
# 333                                              0.000000
# 334                                             -0.055556
# 335                                              0.055556
#
# variable  value__time_reversal_asymmetry_statistic__lag_2  \
# id
# 2                                                  0.0000
# 3                                                  0.0000
# 4                                                  0.0000
# 5                                                  0.0000
# 6                                                  0.0000
# ..                                                    ...
# 331                                               -0.0625
# 332                                               -0.0625
# 333                                                0.0000
# 334                                               -0.0625
# 335                                               -0.0625
#
# variable  value__time_reversal_asymmetry_statistic__lag_3  \
# id
# 2                                                0.000000
# 3                                                0.000000
# 4                                                0.000000
# 5                                                0.000000
# 6                                                0.000000
# ..                                                    ...
# 331                                             -0.714286
# 332                                             -0.142857
# 333                                             -0.142857
# 334                                             -0.142857
# 335                                             -0.142857
#
# variable  value__value_count__value_0  value__value_count__value_1  \
# id
# 2                                 2.0                          0.0
# 3                                 3.0                          0.0
# 4                                 4.0                          0.0
# 5                                 4.0                          0.0
# 6                                 5.0                          0.0
# ..                                ...                          ...
# 331                              11.0                          8.0
# 332                              12.0                          8.0
# 333                              13.0                          7.0
# 334                              12.0                          8.0
# 335                              12.0                          8.0
#
# variable  value__variance  feature_last_value  Population
# id
# 2                0.000000                 0.0       34300
# 3                0.000000                 0.0       34300
# 4                0.000000                 0.0       34300
# 5                0.640000                 2.0       34300
# 6                0.555556                 0.0       34300
# ..                    ...                 ...         ...
# 331              0.547500                 0.0       34300
# 332              0.240000                 0.0       34300
# 333              0.227500                 0.0       34300
# 334              0.240000                 1.0       34300
# 335              0.240000                 1.0       34300
#
# [334 rows x 339 columns]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[i][1]) for i in range(len(ts_features))]

isp = 283   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 1
# 100%|██████████| 51/51 [01:43<00:00,  2.04s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 2
# 100%|██████████| 51/51 [01:57<00:00,  2.31s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 3
# 100%|██████████| 51/51 [02:02<00:00,  2.40s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 4
# 100%|██████████| 51/51 [01:55<00:00,  2.27s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 5
# 100%|██████████| 51/51 [01:53<00:00,  2.22s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 6
# 100%|██████████| 51/51 [01:54<00:00,  2.25s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 7
# 100%|██████████| 51/51 [01:56<00:00,  2.28s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 8
# 100%|██████████| 51/51 [02:09<00:00,  2.53s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 9
# 100%|██████████| 51/51 [01:58<00:00,  2.33s/it]

# %%
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = PoliceDistrict[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[284:], temp_pred[284:])
    MAE = mean_absolute_error(y_true[284:], temp_pred[284:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(PoliceDistrict)
avg_MAE = total_MAE/len(PoliceDistrict)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# Mean Squared Error for district SOUTHEAST = 0.5366764705882353
# Mean Absolute Error for district SOUTHEAST = 0.5986274509803922
#
#
# Mean Squared Error for district NORTHWEST = 0.9829450980392158
# Mean Absolute Error for district NORTHWEST = 0.7243137254901961
#
#
# Mean Squared Error for district EASTERN = 1.4234254901960786
# Mean Absolute Error for district EASTERN = 0.9531372549019607
#
#
# Mean Squared Error for district NORTHERN = 0.5416803921568627
# Mean Absolute Error for district NORTHERN = 0.5707843137254902
#
#
# Mean Squared Error for district SOUTHERN = 0.8342254901960784
# Mean Absolute Error for district SOUTHERN = 0.7582352941176472
#
#
# Mean Squared Error for district SOUTHWEST = 0.5919039215686274
# Mean Absolute Error for district SOUTHWEST = 0.6570588235294117
#
#
# Mean Squared Error for district NORTHEAST = 1.2115882352941174
# Mean Absolute Error for district NORTHEAST = 0.8745098039215685
#
#
# Mean Squared Error for district WESTERN = 1.0264764705882354
# Mean Absolute Error for district WESTERN = 0.8762745098039215
#
#
# Mean Squared Error for district CENTRAL = 0.5556624842047931
# Mean Absolute Error for district CENTRAL = 0.5980751633986927
#
#
# Average of Mean Squared Error = 0.8560648947591383
# Average of Mean Absolute Error = 0.7345573710965866

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/With_Census/Sub_Crime/%s/Predicted_Crime_Vs_True_Crime_RFR.jpg'%crime_type)
