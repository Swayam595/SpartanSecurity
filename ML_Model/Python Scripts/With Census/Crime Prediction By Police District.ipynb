# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
if not os.path.exists('../../Graphs/With_Census/Expanding_Window'):
    os.mkdir('../../Graphs/With_Census/Expanding_Window')

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../../Clean Dataset/BPD_Part_1_Victim_Based_Crime_Data.csv')
data.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     CrimeDate CrimeTime CrimeCode           Location     Description  \
# 0  06/06/2020  15:32:00        4E   800 RICHWOOD AVE  COMMON ASSAULT
# 1  06/06/2020  09:16:00        5C  6000 AMBERWOOD RD        BURGLARY
# 2  06/06/2020  13:23:00        6G    1100 ORLEANS ST         LARCENY
# 3  06/06/2020  08:35:00        6G     2700 BERYL AVE         LARCENY
# 4  06/06/2020  08:35:00        6G     2700 BERYL AVE         LARCENY
#
#   Inside/Outside Weapon Post   District           Neighborhood  Longitude  \
# 0              I    NaN  524   NORTHERN        RICHNOR SPRINGS -76.604920
# 1              I    NaN  443  NORTHEAST              FRANKFORD -76.543350
# 2              I    NaN  211    EASTERN  PLEASENT VIEW GARDENS -76.602911
# 3              I    NaN  333    EASTERN          BIDDLE STREET -76.579613
# 4              I    NaN  333    EASTERN          BIDDLE STREET -76.579613
#
#     Latitude  Location 1               Premise  vri_name1  Total Incidents
# 0  39.346381         NaN     ROW/TOWNHOUSE-OCC        NaN                1
# 1  39.316302         NaN  APT/CONDO - OCCUPIED        NaN                1
# 2  39.294721         NaN     ROW/TOWNHOUSE-OCC        NaN                1
# 3  39.303053         NaN     OTHER/RESIDENTIAL  Eastern 2                1
# 4  39.303053         NaN     OTHER/RESIDENTIAL  Eastern 2                1

# %%
data.describe()
# Out:
#            Longitude       Latitude  Location 1  Total Incidents
# count  292522.000000  292522.000000         0.0         293687.0
# mean      -76.617597      39.306884         NaN              1.0
# std         0.043687       0.029655         NaN              0.0
# min       -81.529189      37.577262         NaN              1.0
# 25%       -76.649274      39.288340         NaN              1.0
# 50%       -76.614162      39.303115         NaN              1.0
# 75%       -76.587114      39.327111         NaN              1.0
# max       -76.383228      39.661332         NaN              1.0

# %%
columns_in_use = ['CrimeDate', 'District']
columns_in_use
# Out:
# ['CrimeDate', 'District']

# %%
data = data[columns_in_use]
data.head()
# Out:
#     CrimeDate   District
# 0  06/06/2020   NORTHERN
# 1  06/06/2020  NORTHEAST
# 2  06/06/2020    EASTERN
# 3  06/06/2020    EASTERN
# 4  06/06/2020    EASTERN

# %%
data.describe()
# Out:
#          CrimeDate   District
# count       293687     293687
# unique        2418         10
# top     04/27/2015  NORTHEAST
# freq           389      44236

# %%
null_count = 0

for i in columns_in_use:
    rows_with_null_values = data[data[i].isnull()].index
    print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_null_values)))
    data = data.drop(rows_with_null_values, axis = 0)
    null_count += len(rows_with_null_values)

print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))
# Out:
# Number of Rows with null values in Column CrimeDate = 0
# Number of Rows with null values in Column District = 0
# Number of rows droped =  0
# Number of rows after droping null values =  293687
# Data Frame Shape:
# 	 Number of Rows = 293687
# 	 Number of Columns = 2

# %% [markdown]
# ## Droping Rows with Unknown Police Districts

# %%
rows_with_unknowon_district = data[data['District'] == 'UNKNOWN'].index
print ('Number of Rows with null values in Column %s = %s'%(i, len(rows_with_unknowon_district)))
data = data.drop(rows_with_unknowon_district, axis = 0)

null_count += len(rows_with_unknowon_district)
print ('Number of rows droped = ', null_count)
print ('Number of rows after droping null values = ', data.shape[0])
print ('Data Frame Shape: \n\t Number of Rows = %s \n\t Number of Columns = %s '%(data.shape[0], data.shape[1]))
# Out:
# Number of Rows with null values in Column District = 337
# Number of rows droped =  337
# Number of rows after droping null values =  293350
# Data Frame Shape:
# 	 Number of Rows = 293350
# 	 Number of Columns = 2

# %%
data['CrimeDate']  = pd.to_datetime(data['CrimeDate'])
data.head()
# Out:
#    CrimeDate   District
# 0 2020-06-06   NORTHERN
# 1 2020-06-06  NORTHEAST
# 2 2020-06-06    EASTERN
# 3 2020-06-06    EASTERN
# 4 2020-06-06    EASTERN

# %% [markdown]
# ## Creating Different Time features

# %%
day_of_week = data['CrimeDate'].dt.dayofweek
week = data['CrimeDate'].dt.week
month = data['CrimeDate'].dt.month
year = data['CrimeDate'].dt.year

data['Day'] = day_of_week
data['Week'] = week
data['Month'] = month
data['Year'] = year

data.head()
# Out:
#    CrimeDate   District  Day  Week  Month  Year
# 0 2020-06-06   NORTHERN    5    23      6  2020
# 1 2020-06-06  NORTHEAST    5    23      6  2020
# 2 2020-06-06    EASTERN    5    23      6  2020
# 3 2020-06-06    EASTERN    5    23      6  2020
# 4 2020-06-06    EASTERN    5    23      6  2020

# %% [markdown]
# ## Consider data from 2014 and beyond

# %%
data = data[data['Year']>= 2014]

# %%
data.describe()
# Out:
#                  Day           Week          Month           Year
# count  293270.000000  293270.000000  293270.000000  293270.000000
# mean        2.957531      26.589849       6.514482    2016.687350
# std         1.989160      14.788523       3.392183       1.805081
# min         0.000000       1.000000       1.000000    2014.000000
# 25%         1.000000      14.000000       4.000000    2015.000000
# 50%         3.000000      26.000000       7.000000    2017.000000
# 75%         5.000000      39.000000       9.000000    2018.000000
# max         6.000000      53.000000      12.000000    2020.000000

# %% [markdown]
# ## Creating Times Series Dataset

# %%
def ts_data_creation(group_by_parameter, data):
    if group_by_parameter == 'Week' or group_by_parameter == 'Month':
        pass
    else:
        raise AttributeError('group_by_parameter')
    
    if group_by_parameter == 'Week':
        parameter_name = 'Week_Number'
    else:
        parameter_name = 'Month_Number'
        
    PoliceDistricts = set(data['District'])
    ts_data = {}
    for district in PoliceDistricts:
        ts_data_temp = []
        for year_num, year_value in data[data['District'] == district].groupby('Year'):
            for parameter_num, parameter_value in year_value[year_value['District'] == district].groupby(group_by_parameter):
                total_crimes = len(parameter_value)
                year_parameter_num = "%s_%s"%(year_num, parameter_num)
                ts_data_temp.append([year_num] + [district, parameter_num, year_parameter_num] + [total_crimes])
        ts_data_temp = pd.DataFrame(ts_data_temp, columns = ['Year', 'PoliceDistrict', parameter_name, 'Year_%s'%parameter_name, 'NoOfCrimes'])
        ts_data[district] = ts_data_temp
    
    return ts_data

# %%
ts_data_week = ts_data_creation('Week', data)
ts_data_week
# Out:
# {'WESTERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014        WESTERN            1           2014_1          72
#  1    2014        WESTERN            2           2014_2          71
#  2    2014        WESTERN            3           2014_3          68
#  3    2014        WESTERN            4           2014_4          41
#  4    2014        WESTERN            5           2014_5          81
#  ..    ...            ...          ...              ...         ...
#  332  2020        WESTERN           19          2020_19          43
#  333  2020        WESTERN           20          2020_20          59
#  334  2020        WESTERN           21          2020_21          51
#  335  2020        WESTERN           22          2020_22          63
#  336  2020        WESTERN           23          2020_23          34
#
#  [337 rows x 5 columns],
#  'CENTRAL':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014        CENTRAL            1           2014_1          68
#  1    2014        CENTRAL            2           2014_2          77
#  2    2014        CENTRAL            3           2014_3         114
#  3    2014        CENTRAL            4           2014_4          76
#  4    2014        CENTRAL            5           2014_5          75
#  ..    ...            ...          ...              ...         ...
#  332  2020        CENTRAL           19          2020_19          58
#  333  2020        CENTRAL           20          2020_20          48
#  334  2020        CENTRAL           21          2020_21          68
#  335  2020        CENTRAL           22          2020_22          72
#  336  2020        CENTRAL           23          2020_23          46
#
#  [337 rows x 5 columns],
#  'SOUTHERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014       SOUTHERN            1           2014_1          90
#  1    2014       SOUTHERN            2           2014_2          66
#  2    2014       SOUTHERN            3           2014_3          77
#  3    2014       SOUTHERN            4           2014_4          84
#  4    2014       SOUTHERN            5           2014_5          72
#  ..    ...            ...          ...              ...         ...
#  332  2020       SOUTHERN           19          2020_19          71
#  333  2020       SOUTHERN           20          2020_20          72
#  334  2020       SOUTHERN           21          2020_21          56
#  335  2020       SOUTHERN           22          2020_22          66
#  336  2020       SOUTHERN           23          2020_23          45
#
#  [337 rows x 5 columns],
#  'NORTHWEST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      NORTHWEST            1           2014_1          96
#  1    2014      NORTHWEST            2           2014_2          87
#  2    2014      NORTHWEST            3           2014_3          84
#  3    2014      NORTHWEST            4           2014_4          66
#  4    2014      NORTHWEST            5           2014_5          84
#  ..    ...            ...          ...              ...         ...
#  332  2020      NORTHWEST           19          2020_19          52
#  333  2020      NORTHWEST           20          2020_20          72
#  334  2020      NORTHWEST           21          2020_21          64
#  335  2020      NORTHWEST           22          2020_22          76
#  336  2020      NORTHWEST           23          2020_23          52
#
#  [337 rows x 5 columns],
#  'SOUTHWEST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      SOUTHWEST            1           2014_1          85
#  1    2014      SOUTHWEST            2           2014_2          84
#  2    2014      SOUTHWEST            3           2014_3          90
#  3    2014      SOUTHWEST            4           2014_4          72
#  4    2014      SOUTHWEST            5           2014_5          81
#  ..    ...            ...          ...              ...         ...
#  332  2020      SOUTHWEST           19          2020_19          83
#  333  2020      SOUTHWEST           20          2020_20          72
#  334  2020      SOUTHWEST           21          2020_21          65
#  335  2020      SOUTHWEST           22          2020_22          75
#  336  2020      SOUTHWEST           23          2020_23          28
#
#  [337 rows x 5 columns],
#  'EASTERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014        EASTERN            1           2014_1          67
#  1    2014        EASTERN            2           2014_2          68
#  2    2014        EASTERN            3           2014_3          77
#  3    2014        EASTERN            4           2014_4          66
#  4    2014        EASTERN            5           2014_5          85
#  ..    ...            ...          ...              ...         ...
#  332  2020        EASTERN           19          2020_19          93
#  333  2020        EASTERN           20          2020_20          58
#  334  2020        EASTERN           21          2020_21          44
#  335  2020        EASTERN           22          2020_22          62
#  336  2020        EASTERN           23          2020_23          38
#
#  [337 rows x 5 columns],
#  'SOUTHEAST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      SOUTHEAST            1           2014_1         133
#  1    2014      SOUTHEAST            2           2014_2         113
#  2    2014      SOUTHEAST            3           2014_3         125
#  3    2014      SOUTHEAST            4           2014_4         114
#  4    2014      SOUTHEAST            5           2014_5         140
#  ..    ...            ...          ...              ...         ...
#  332  2020      SOUTHEAST           19          2020_19          65
#  333  2020      SOUTHEAST           20          2020_20          99
#  334  2020      SOUTHEAST           21          2020_21          85
#  335  2020      SOUTHEAST           22          2020_22          69
#  336  2020      SOUTHEAST           23          2020_23          35
#
#  [337 rows x 5 columns],
#  'NORTHERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014       NORTHERN            1           2014_1         101
#  1    2014       NORTHERN            2           2014_2          95
#  2    2014       NORTHERN            3           2014_3          93
#  3    2014       NORTHERN            4           2014_4          86
#  4    2014       NORTHERN            5           2014_5          80
#  ..    ...            ...          ...              ...         ...
#  332  2020       NORTHERN           19          2020_19          54
#  333  2020       NORTHERN           20          2020_20          81
#  334  2020       NORTHERN           21          2020_21          71
#  335  2020       NORTHERN           22          2020_22          58
#  336  2020       NORTHERN           23          2020_23          38
#
#  [337 rows x 5 columns],
#  'NORTHEAST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      NORTHEAST            1           2014_1         118
#  1    2014      NORTHEAST            2           2014_2         112
#  2    2014      NORTHEAST            3           2014_3         139
#  3    2014      NORTHEAST            4           2014_4         118
#  4    2014      NORTHEAST            5           2014_5         108
#  ..    ...            ...          ...              ...         ...
#  332  2020      NORTHEAST           19          2020_19          82
#  333  2020      NORTHEAST           20          2020_20          85
#  334  2020      NORTHEAST           21          2020_21          88
#  335  2020      NORTHEAST           22          2020_22          76
#  336  2020      NORTHEAST           23          2020_23          76
#
#  [337 rows x 5 columns]}

# %% [markdown]
# ## Importing Population Dataset

# %%
population_data = pd.read_csv('../../Clean Dataset/Population_By_PoliceDistrict.csv')
population_data
# Out:
#   Police District  Population
# 0         CENTRAL       34300
# 1        NORTHERN       95194
# 2       NORTHWEST       78736
# 3         WESTERN       39691
# 4         EASTERN       42653
# 5       NORTHEAST      155040
# 6       SOUTHEAST       69535
# 7        SOUTHERN       60141
# 8       SOUTHWEST       68743

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      NORTHEAST            1           2014_1         118
# 1  2014      NORTHEAST            2           2014_2         112
# 2  2014      NORTHEAST            3           2014_3         139
# 3  2014      NORTHEAST            4           2014_4         118
# 4  2014      NORTHEAST            5           2014_5         108

# %%
districts = set(data['District'])
df = pd.DataFrame()

for i in districts:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year 2019', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../../Graphs/With_Census/Expanding_Window/policeDistrictCrimes.jpg')
plt.show()

# %%
fig = plt.figure()
dist = list(districts)
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % dist[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/With_Census/Expanding_Window/True_Crime_Baltimre.jpg')

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
districts = set(data['District'])
df_shift = pd.DataFrame()
temp_df = []
for district in districts:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.28it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.30it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.99it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.21it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.89it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.21it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.12it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.18it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.22it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)
# (336, 754)
# (336, 349)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ### Appending Population to time series features

# %%
districts = data['District'].unique()
i = 0
for district in districts:
    population = population_data[population_data['Police District'] == district]['Population'].values[0]
    ts_features[i][0]['Population'] = [population] * ts_features[i][0].shape[0]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 284   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

# #### Evaluation of random forest regressor prediction with actual value
    
# y = []
# prediction = {}
# for i in range(len(temp_df)):
#     y_true = np.array(temp_df[i][1].tolist())
#     y_predicted = np.array(y_pred[i])
#     temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
#     y.append(temp)
    
#     dist = list(districts)[i]
#     temp_pred = [np.nan] + y_pred[i]
#     MSE = mean_squared_error(y_true[311:], temp_pred[311:])
#     MAE = mean_absolute_error(y_true[311:], temp_pred[311:])
#     prediction[dist] = {'MSE': MSE, 'MAE': MAE}
#     print ('Mean Squared Error for district %s = %s'%(dist, MSE))
#     print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

# #### Finding average of MSE and MAE

# total_MSE = 0
# total_MAE = 0
# for i in prediction:
#     total_MSE += prediction[i]['MSE']
#     total_MAE += prediction[i]['MAE']
    
# avg_MSE = total_MSE/len(districts)
# avg_MAE = total_MAE/len(districts)

# print ('Average of Mean Squared Error = %s'%avg_MSE)
# print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 1
# 100%|██████████| 51/51 [02:14<00:00,  2.63s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 2
# 100%|██████████| 51/51 [02:00<00:00,  2.36s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 3
# 100%|██████████| 51/51 [02:04<00:00,  2.45s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 4
# 100%|██████████| 51/51 [02:04<00:00,  2.44s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 5
# 100%|██████████| 51/51 [01:53<00:00,  2.23s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 6
# 100%|██████████| 51/51 [02:14<00:00,  2.63s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 7
# 100%|██████████| 51/51 [02:02<00:00,  2.41s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 8
# 100%|██████████| 51/51 [02:03<00:00,  2.42s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 9
# 100%|██████████| 51/51 [02:06<00:00,  2.48s/it]

# %%
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[285:], temp_pred[285:])
    MAE = mean_absolute_error(y_true[285:], temp_pred[285:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# Mean Squared Error for district NORTHERN = 186.36085686274507
# Mean Absolute Error for district NORTHERN = 11.388431372549018
#
#
# Mean Squared Error for district NORTHEAST = 291.24485686274517
# Mean Absolute Error for district NORTHEAST = 13.888039215686273
#
#
# Mean Squared Error for district EASTERN = 241.9237549019608
# Mean Absolute Error for district EASTERN = 12.387254901960784
#
#
# Mean Squared Error for district SOUTHEAST = 348.6542039215687
# Mean Absolute Error for district SOUTHEAST = 12.03921568627451
#
#
# Mean Squared Error for district SOUTHWEST = 206.0124725490196
# Mean Absolute Error for district SOUTHWEST = 11.15235294117647
#
#
# Mean Squared Error for district SOUTHERN = 197.0781588235294
# Mean Absolute Error for district SOUTHERN = 10.855490196078433
#
#
# Mean Squared Error for district NORTHWEST = 349.16543333333334
# Mean Absolute Error for district NORTHWEST = 14.21705882352941
#
#
# Mean Squared Error for district WESTERN = 267.54803333333336
# Mean Absolute Error for district WESTERN = 13.109607843137253
#
#
# Mean Squared Error for district CENTRAL = 375.79246666666666
# Mean Absolute Error for district CENTRAL = 15.231764705882354
#
#
# Average of Mean Squared Error = 273.7533596949891
# Average of Mean Absolute Error = 12.696579520697167

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/With_Census/Expanding_Window/Predicted_Crime_Vs_True_Crime_RFR.jpg')

# %% [markdown]
# #### Traing Multilayer Perceptron regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 310   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    MLPR = MLPRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        MLPR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = MLPR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of multilayer perceptron regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)

# %% [markdown]
# #### MLPR prediction visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Predicted_Crime_Vs_True_Crime_MLPRegressor.jpg')

# %% [markdown]
# #### Traing support vector regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[0][1]) for i in range(len(ts_features))]

isp = 310   # index of where to start the predictions
assert isp > 0

index = 0
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    SVRegr = SVR()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        SVRegr.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = SVRegr.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1

#### Evaluation of support vector regressor prediction with actual value
    
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = list(districts)[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[11:], temp_pred[11:])
    MAE = mean_absolute_error(y_true[11:], temp_pred[11:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))
    
#### Finding average of MSE and MAE
    
total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(districts)
avg_MAE = total_MAE/len(districts)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)

# %% [markdown]
# #### SVR visualization

# %%
fig = plt.figure()
dist = list(districts)

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % dist[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../Graphs/Predicted_Crime_Vs_True_Crime_SVR.jpg')
