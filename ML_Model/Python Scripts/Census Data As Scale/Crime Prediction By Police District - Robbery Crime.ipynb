# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
crime_type = input('Enter Crime Type: ')
# Out:
# Enter Crime Type: Robbery

# %%
if not os.path.exists('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s'%crime_type):
    os.makedirs('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s'%crime_type)

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../../Clean Dataset/Sub Crimes By Neighborhood/Preprocessed_data/Preprocessed_%s_data.csv'%crime_type)
data.head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      NORTHEAST            1           2014_1          81
# 1  2014      NORTHEAST            2           2014_2          75
# 2  2014      NORTHEAST            3           2014_3          99
# 3  2014      NORTHEAST            4           2014_4          79
# 4  2014      NORTHEAST            5           2014_5          82

# %%
data.describe()
# Out:
#               Year  Week_Number   NoOfCrimes
# count  3024.000000  3024.000000  3024.000000
# mean   2016.735119    25.586310    67.396825
# std       1.870681    15.096201    23.814268
# min    2014.000000     1.000000    12.000000
# 25%    2015.000000    12.750000    49.000000
# 50%    2017.000000    25.000000    64.000000
# 75%    2018.000000    39.000000    83.000000
# max    2020.000000    53.000000   192.000000

# %%
PoliceDistrict = data['PoliceDistrict'].unique()
ts_data_week = {}
for district in PoliceDistrict:
    ts_data_week[district] = data[data['PoliceDistrict'] == district]

# %% [markdown]
# ## Importing Population Dataset

# %%
population_data = pd.read_csv('../../Clean Dataset/Population_By_PoliceDistrict.csv')
population_data
# Out:
#   Police District  Population
# 0         CENTRAL       34300
# 1        NORTHERN       95194
# 2       NORTHWEST       78736
# 3         WESTERN       39691
# 4         EASTERN       42653
# 5       NORTHEAST      155040
# 6       SOUTHEAST       69535
# 7        SOUTHERN       60141
# 8       SOUTHWEST       68743

# %% [markdown]
# ### Using Population as a Scale
# Our goal is to find number of crimes in a police district per 10,000 people

# %%
districts = data['PoliceDistrict'].unique()
for district in districts:
    number_of_people = population_data[population_data['Police District'] == district]['Population'].values[0]
    crime_per_10k = ts_data_week[district]['NoOfCrimes'] / number_of_people * 10000
    ts_data_week[district]['NoOfCrimes'] = crime_per_10k.round(0).astype(int)
ts_data_week
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# {'NORTHEAST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      NORTHEAST            1           2014_1           5
#  1    2014      NORTHEAST            2           2014_2           5
#  2    2014      NORTHEAST            3           2014_3           6
#  3    2014      NORTHEAST            4           2014_4           5
#  4    2014      NORTHEAST            5           2014_5           5
#  ..    ...            ...          ...              ...         ...
#  331  2020      NORTHEAST           19          2020_19           3
#  332  2020      NORTHEAST           20          2020_20           3
#  333  2020      NORTHEAST           21          2020_21           3
#  334  2020      NORTHEAST           22          2020_22           3
#  335  2020      NORTHEAST           23          2020_23           2
#
#  [336 rows x 5 columns],
#  'NORTHERN':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  336  2014       NORTHERN            1           2014_1           8
#  337  2014       NORTHERN            2           2014_2           8
#  338  2014       NORTHERN            3           2014_3           8
#  339  2014       NORTHERN            4           2014_4           8
#  340  2014       NORTHERN            5           2014_5           7
#  ..    ...            ...          ...              ...         ...
#  667  2020       NORTHERN           19          2020_19           5
#  668  2020       NORTHERN           20          2020_20           5
#  669  2020       NORTHERN           21          2020_21           5
#  670  2020       NORTHERN           22          2020_22           4
#  671  2020       NORTHERN           23          2020_23           3
#
#  [336 rows x 5 columns],
#  'CENTRAL':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  672   2014        CENTRAL            1           2014_1          14
#  673   2014        CENTRAL            2           2014_2          17
#  674   2014        CENTRAL            3           2014_3          21
#  675   2014        CENTRAL            4           2014_4          15
#  676   2014        CENTRAL            5           2014_5          14
#  ...    ...            ...          ...              ...         ...
#  1003  2020        CENTRAL           19          2020_19           8
#  1004  2020        CENTRAL           20          2020_20           8
#  1005  2020        CENTRAL           21          2020_21          11
#  1006  2020        CENTRAL           22          2020_22           9
#  1007  2020        CENTRAL           23          2020_23          10
#
#  [336 rows x 5 columns],
#  'EASTERN':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  1008  2014        EASTERN            1           2014_1          11
#  1009  2014        EASTERN            2           2014_2          10
#  1010  2014        EASTERN            3           2014_3          13
#  1011  2014        EASTERN            4           2014_4          12
#  1012  2014        EASTERN            5           2014_5          12
#  ...    ...            ...          ...              ...         ...
#  1339  2020        EASTERN           19          2020_19          13
#  1340  2020        EASTERN           20          2020_20           8
#  1341  2020        EASTERN           21          2020_21           4
#  1342  2020        EASTERN           22          2020_22           8
#  1343  2020        EASTERN           23          2020_23           4
#
#  [336 rows x 5 columns],
#  'WESTERN':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  1344  2014        WESTERN            1           2014_1          12
#  1345  2014        WESTERN            2           2014_2          13
#  1346  2014        WESTERN            3           2014_3          13
#  1347  2014        WESTERN            4           2014_4           8
#  1348  2014        WESTERN            5           2014_5          12
#  ...    ...            ...          ...              ...         ...
#  1675  2020        WESTERN           19          2020_19           7
#  1676  2020        WESTERN           20          2020_20           7
#  1677  2020        WESTERN           21          2020_21           8
#  1678  2020        WESTERN           22          2020_22           8
#  1679  2020        WESTERN           23          2020_23           3
#
#  [336 rows x 5 columns],
#  'NORTHWEST':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  1680  2014      NORTHWEST            1           2014_1          10
#  1681  2014      NORTHWEST            2           2014_2           8
#  1682  2014      NORTHWEST            3           2014_3           8
#  1683  2014      NORTHWEST            4           2014_4           7
#  1684  2014      NORTHWEST            5           2014_5           8
#  ...    ...            ...          ...              ...         ...
#  2011  2020      NORTHWEST           19          2020_19           4
#  2012  2020      NORTHWEST           20          2020_20           6
#  2013  2020      NORTHWEST           21          2020_21           4
#  2014  2020      NORTHWEST           22          2020_22           5
#  2015  2020      NORTHWEST           23          2020_23           4
#
#  [336 rows x 5 columns],
#  'SOUTHEAST':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  2016  2014      SOUTHEAST            1           2014_1          13
#  2017  2014      SOUTHEAST            2           2014_2          11
#  2018  2014      SOUTHEAST            3           2014_3          14
#  2019  2014      SOUTHEAST            4           2014_4          14
#  2020  2014      SOUTHEAST            5           2014_5          15
#  ...    ...            ...          ...              ...         ...
#  2347  2020      SOUTHEAST           19          2020_19           6
#  2348  2020      SOUTHEAST           20          2020_20          10
#  2349  2020      SOUTHEAST           21          2020_21           9
#  2350  2020      SOUTHEAST           22          2020_22           6
#  2351  2020      SOUTHEAST           23          2020_23           3
#
#  [336 rows x 5 columns],
#  'SOUTHERN':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  2352  2014       SOUTHERN            1           2014_1          11
#  2353  2014       SOUTHERN            2           2014_2           8
#  2354  2014       SOUTHERN            3           2014_3          10
#  2355  2014       SOUTHERN            4           2014_4          10
#  2356  2014       SOUTHERN            5           2014_5           9
#  ...    ...            ...          ...              ...         ...
#  2683  2020       SOUTHERN           19          2020_19           7
#  2684  2020       SOUTHERN           20          2020_20           8
#  2685  2020       SOUTHERN           21          2020_21           5
#  2686  2020       SOUTHERN           22          2020_22           8
#  2687  2020       SOUTHERN           23          2020_23           5
#
#  [336 rows x 5 columns],
#  'SOUTHWEST':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  2688  2014      SOUTHWEST            1           2014_1           9
#  2689  2014      SOUTHWEST            2           2014_2           9
#  2690  2014      SOUTHWEST            3           2014_3          10
#  2691  2014      SOUTHWEST            4           2014_4           8
#  2692  2014      SOUTHWEST            5           2014_5           9
#  ...    ...            ...          ...              ...         ...
#  3019  2020      SOUTHWEST           19          2020_19           5
#  3020  2020      SOUTHWEST           20          2020_20           5
#  3021  2020      SOUTHWEST           21          2020_21           5
#  3022  2020      SOUTHWEST           22          2020_22           4
#  3023  2020      SOUTHWEST           23          2020_23           3
#
#  [336 rows x 5 columns]}

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      NORTHEAST            1           2014_1           5
# 1  2014      NORTHEAST            2           2014_2           5
# 2  2014      NORTHEAST            3           2014_3           6
# 3  2014      NORTHEAST            4           2014_4           5
# 4  2014      NORTHEAST            5           2014_5           5

# %%
df = pd.DataFrame()

for i in PoliceDistrict:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/policeDistrictCrimes.jpg'%crime_type)
plt.show()

# %%
fig = plt.figure()
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/True_Crime_Baltimre.jpg'%crime_type)

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
df_shift = pd.DataFrame()
temp_df = []
for district in PoliceDistrict:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.84it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.82it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.32it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.80it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.32it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.83it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.35it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.93it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.18it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (335, 754)
# (335, 344)
# (335, 754)
# (335, 343)
# (335, 754)
# (335, 349)
# (335, 754)
# (335, 349)
# (335, 754)
# (335, 344)
# (335, 754)
# (335, 344)
# (335, 754)
# (335, 349)
# (335, 754)
# (335, 349)
# (335, 754)
# (335, 344)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[i][1]) for i in range(len(ts_features))]

isp = 283   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 1
# 100%|██████████| 51/51 [03:54<00:00,  4.59s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 2
# 100%|██████████| 51/51 [01:44<00:00,  2.05s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 3
# 100%|██████████| 51/51 [01:52<00:00,  2.21s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 4
# 100%|██████████| 51/51 [01:57<00:00,  2.30s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 5
# 100%|██████████| 51/51 [01:56<00:00,  2.28s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 6
# 100%|██████████| 51/51 [01:51<00:00,  2.18s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 7
# 100%|██████████| 51/51 [01:46<00:00,  2.09s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 8
# 100%|██████████| 51/51 [01:51<00:00,  2.18s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 9
# 100%|██████████| 51/51 [01:43<00:00,  2.03s/it]

# %%
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = PoliceDistrict[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[284:], temp_pred[284:])
    MAE = mean_absolute_error(y_true[284:], temp_pred[284:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(PoliceDistrict)
avg_MAE = total_MAE/len(PoliceDistrict)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# Mean Squared Error for district NORTHEAST = 1.2310745098039213
# Mean Absolute Error for district NORTHEAST = 0.896078431372549
#
#
# Mean Squared Error for district NORTHERN = 1.9951450980392158
# Mean Absolute Error for district NORTHERN = 1.0733333333333335
#
#
# Mean Squared Error for district CENTRAL = 15.609149019607843
# Mean Absolute Error for district CENTRAL = 3.174117647058823
#
#
# Mean Squared Error for district EASTERN = 5.6598058823529405
# Mean Absolute Error for district EASTERN = 1.8476470588235292
#
#
# Mean Squared Error for district WESTERN = 5.9371
# Mean Absolute Error for district WESTERN = 2.0445098039215686
#
#
# Mean Squared Error for district NORTHWEST = 5.274625490196079
# Mean Absolute Error for district NORTHWEST = 1.4582352941176469
#
#
# Mean Squared Error for district SOUTHEAST = 5.963162745098039
# Mean Absolute Error for district SOUTHEAST = 1.9535294117647062
#
#
# Mean Squared Error for district SOUTHERN = 4.372345098039215
# Mean Absolute Error for district SOUTHERN = 1.7498039215686276
#
#
# Mean Squared Error for district SOUTHWEST = 2.442378431372549
# Mean Absolute Error for district SOUTHWEST = 1.3111764705882352
#
#
# Average of Mean Squared Error = 5.387198474945533
# Average of Mean Absolute Error = 1.7231590413943352

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/Predicted_Crime_Vs_True_Crime_RFR.jpg'%crime_type)
