# %% [markdown]
# ## Library Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

sns.set()

# %%
crime_type = input('Enter Crime Type: ')
# Out:
# Enter Crime Type: Homicide

# %%
if not os.path.exists('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s'%crime_type):
    os.makedirs('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s'%crime_type)

# %% [markdown]
# ## Importing Baltimore calls for service dataset

# %%
data = pd.read_csv('../../Clean Dataset/Sub Crimes By Neighborhood/Preprocessed_data/Preprocessed_%s_data.csv'%crime_type)
data.head()
# Out:
#    Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 0  2014      SOUTHEAST            1           2014_1           0
# 1  2014      SOUTHEAST            2           2014_2           0
# 2  2014      SOUTHEAST            3           2014_3           0
# 3  2014      SOUTHEAST            4           2014_4           0
# 4  2014      SOUTHEAST            5           2014_5           2

# %%
data.describe()
# Out:
#               Year  Week_Number   NoOfCrimes
# count  3024.000000  3024.000000  3024.000000
# mean   2016.735119    25.586310     0.635251
# std       1.870681    15.096201     0.855154
# min    2014.000000     1.000000     0.000000
# 25%    2015.000000    12.750000     0.000000
# 50%    2017.000000    25.000000     0.000000
# 75%    2018.000000    39.000000     1.000000
# max    2020.000000    53.000000     5.000000

# %%
PoliceDistrict = data['PoliceDistrict'].unique()
ts_data_week = {}
for district in PoliceDistrict:
    ts_data_week[district] = data[data['PoliceDistrict'] == district]

# %% [markdown]
# ## Importing Population Dataset

# %%
population_data = pd.read_csv('../../Clean Dataset/Population_By_PoliceDistrict.csv')
population_data
# Out:
#   Police District  Population
# 0         CENTRAL       34300
# 1        NORTHERN       95194
# 2       NORTHWEST       78736
# 3         WESTERN       39691
# 4         EASTERN       42653
# 5       NORTHEAST      155040
# 6       SOUTHEAST       69535
# 7        SOUTHERN       60141
# 8       SOUTHWEST       68743

# %% [markdown]
# ### Using Population as a Scale
# Our goal is to find number of crimes in a police district per 10,000 people

# %%
districts = data['PoliceDistrict'].unique()
for district in districts:
    number_of_people = population_data[population_data['Police District'] == district]['Population'].values[0]
    crime_per_10k = ts_data_week[district]['NoOfCrimes'] / number_of_people * 10000
    ts_data_week[district]['NoOfCrimes'] = crime_per_10k.round(0).astype(int)
ts_data_week
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# {'SOUTHEAST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  0    2014      SOUTHEAST            1           2014_1           0
#  1    2014      SOUTHEAST            2           2014_2           0
#  2    2014      SOUTHEAST            3           2014_3           0
#  3    2014      SOUTHEAST            4           2014_4           0
#  4    2014      SOUTHEAST            5           2014_5           0
#  ..    ...            ...          ...              ...         ...
#  331  2020      SOUTHEAST           19          2020_19           0
#  332  2020      SOUTHEAST           20          2020_20           0
#  333  2020      SOUTHEAST           21          2020_21           0
#  334  2020      SOUTHEAST           22          2020_22           0
#  335  2020      SOUTHEAST           23          2020_23           0
#
#  [336 rows x 5 columns],
#  'NORTHWEST':      Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  336  2014      NORTHWEST            1           2014_1           0
#  337  2014      NORTHWEST            2           2014_2           0
#  338  2014      NORTHWEST            3           2014_3           0
#  339  2014      NORTHWEST            4           2014_4           0
#  340  2014      NORTHWEST            5           2014_5           0
#  ..    ...            ...          ...              ...         ...
#  667  2020      NORTHWEST           19          2020_19           0
#  668  2020      NORTHWEST           20          2020_20           0
#  669  2020      NORTHWEST           21          2020_21           0
#  670  2020      NORTHWEST           22          2020_22           0
#  671  2020      NORTHWEST           23          2020_23           0
#
#  [336 rows x 5 columns],
#  'EASTERN':       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#
Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
#  2688  2014        CENTRAL            1           2014_1           0
#  2689  2014        CENTRAL            2           2014_2           0
#  2690  2014        CENTRAL            3           2014_3           0
#  2691  2014        CENTRAL            4           2014_4           0
#  2692  2014        CENTRAL            5           2014_5           0
#  ...    ...            ...          ...              ...         ...
#  3019  2020        CENTRAL           19          2020_19           0
#  3020  2020        CENTRAL           20          2020_20           1
#  3021  2020        CENTRAL           21          2020_21           0
#  3022  2020        CENTRAL           22          2020_22           0
#  3023  2020        CENTRAL           23          2020_23           1
#
#  [336 rows x 5 columns]}

# %% [markdown]
# # Make Forecasting Frame

# %%
ts_data_week['NORTHEAST'].head()
# Out:
#       Year PoliceDistrict  Week_Number Year_Week_Number  NoOfCrimes
# 2016  2014      NORTHEAST            1           2014_1           0
# 2017  2014      NORTHEAST            2           2014_2           0
# 2018  2014      NORTHEAST            3           2014_3           0
# 2019  2014      NORTHEAST            4           2014_4           0
# 2020  2014      NORTHEAST            5           2014_5           0

# %%
df = pd.DataFrame()

for i in PoliceDistrict:
    values = ts_data_week[i]['NoOfCrimes'].tolist()
    index = ts_data_week[i]['Year_Week_Number'].tolist()
    temp_df = pd.DataFrame(values, columns = [i], index = index)
    df = pd.concat([df, temp_df], axis = 1)
    

df.plot(figsize=(15,8))
plt.xlabel('Week Number of the year', fontsize=20)
plt.ylabel('Crimes', fontsize=20)
plt.title('True Crime Per Police Districts', fontsize=20)
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/policeDistrictCrimes.jpg'%crime_type)
plt.show()

# %%
fig = plt.figure()
i = 0

for pd_col in df:
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    df[pd_col].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Year_Week_Number', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s Police District Weekly Crime Trend' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    i += 1
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/True_Crime_Baltimre.jpg'%crime_type)

# %% [markdown]
# ## Time Series Feature Extraction

# %% [markdown]
# ### Library Dependencies for making forecasting frame and Extracting time series features from it.

# %%
from tsfresh.utilities.dataframe_functions import make_forecasting_frame
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

# %% [markdown]
# ### Takes one police district at a time and creates forecating frame and its output (total cirme) for that district and append it to a list called temp_df.

# %%
df_shift = pd.DataFrame()
temp_df = []
for district in PoliceDistrict:
    temp_shift, temp_y = make_forecasting_frame(ts_data_week[district]['NoOfCrimes'], kind="crimes", max_timeshift=20, rolling_direction=1) 
    temp_df.append([temp_shift, temp_y])

# %% [markdown]
# ### Create Time sereies features from make forecasting frames using tsfresh

# %%
ts_features = []

for i in temp_df:
    X = extract_features(i[0], column_id="id", column_sort="time", column_value="value", 
                             impute_function=impute, show_warnings=False)
    ts_features.append([X, i[1]])
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  5.00it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.37it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.52it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.52it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:03<00:00,  5.33it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.81it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.97it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.01it/s]
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.70it/s]

# %% [markdown]
# ### Removing constant features

# %%
for i in ts_features:
    print (i[0].shape)
    i[0] = i[0].loc[:, i[0].apply(pd.Series.nunique) != 1] 
    print (i[0].shape)
# Out:
# (335, 754)
# (335, 10)
# (335, 754)
# (335, 271)
# (335, 754)
# (335, 287)
# (335, 754)
# (335, 10)
# (335, 754)
# (335, 271)
# (335, 754)
# (335, 271)
# (335, 754)
# (335, 10)
# (335, 754)
# (335, 320)
# (335, 754)
# (335, 286)

# %% [markdown]
# ### Adding a lag of 1 into the extraced time series feature dataframe

# %%
for i in ts_features:
    i[0]["feature_last_value"] = i[1].shift(1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Droping the first row becuase of null value created due ot lag

# %%
for i in ts_features:
    i[0] = i[0].iloc[1:, ]
    i[1] = i[1].iloc[1: ]

# %% [markdown]
# ## Training and Tesing the models
# ### Libray dependencies for different models and their evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import sklearn.utils
import numpy as np
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

import tqdm

# %% [markdown]
# ### Expanding Window Forecast -
# An expanding window refers to a model that train on all available historic data and uses that to make a forecast.
#
# It is an expanding window because it grows as more real observations are collected.

# %% [markdown]
# #### Traing random forest regressor using expanding window forecast approach and random forest regressor performance

# %%
y_pred = [[np.NaN] * len(ts_features[i][1]) for i in range(len(ts_features))]

isp = 283   # index of where to start the predictions
assert isp > 0

index = 0
district = 1
for i in ts_features:
    print ("Current District Number = %s"%district)
    district += 1
    RFR = RandomForestRegressor()
    for j in tqdm.tqdm(range(isp, len(i[1]))):
        RFR.fit(i[0].iloc[:j], i[1][:j])
        y_pred[index][j] = RFR.predict(i[0].iloc[j, :].values.reshape((1, -1)))[0]
    index += 1
# Out:
#   4%|▍         | 2/51 [00:00<00:04, 10.53it/s]
# Current District Number = 1
# 100%|██████████| 51/51 [00:04<00:00, 10.71it/s]
#   2%|▏         | 1/51 [00:00<00:05,  8.78it/s]
# Current District Number = 2
# 100%|██████████| 51/51 [00:05<00:00,  8.74it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 3
# 100%|██████████| 51/51 [00:42<00:00,  1.20it/s]
#   2%|▏         | 1/51 [00:00<00:05,  9.85it/s]
# Current District Number = 4
# 100%|██████████| 51/51 [00:05<00:00, 10.07it/s]
#   2%|▏         | 1/51 [00:00<00:06,  8.05it/s]
# Current District Number = 5
# 100%|██████████| 51/51 [00:05<00:00,  8.78it/s]
#   2%|▏         | 1/51 [00:00<00:06,  7.81it/s]
# Current District Number = 6
# 100%|██████████| 51/51 [00:06<00:00,  7.35it/s]
#   4%|▍         | 2/51 [00:00<00:04, 10.23it/s]
# Current District Number = 7
# 100%|██████████| 51/51 [00:05<00:00, 10.04it/s]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 8
# 100%|██████████| 51/51 [01:20<00:00,  1.58s/it]
#   0%|          | 0/51 [00:00<?, ?it/s]
# Current District Number = 9
# 100%|██████████| 51/51 [00:27<00:00,  1.88it/s]

# %%
y = []
prediction = {}
for i in range(len(temp_df)):
    y_true = np.array(temp_df[i][1].tolist())
    y_predicted = np.array(y_pred[i])
    temp = pd.DataFrame([y_true, y_predicted], index = ['True', 'Pred']).T 
    y.append(temp)
    
    dist = PoliceDistrict[i]
    temp_pred = [np.nan] + y_pred[i]
    MSE = mean_squared_error(y_true[284:], temp_pred[284:])
    MAE = mean_absolute_error(y_true[284:], temp_pred[284:])
    prediction[dist] = {'MSE': MSE, 'MAE': MAE}
    print ('Mean Squared Error for district %s = %s'%(dist, MSE))
    print ('Mean Absolute Error for district %s = %s\n\n'%(dist, MAE))

#### Finding average of MSE and MAE

total_MSE = 0
total_MAE = 0
for i in prediction:
    total_MSE += prediction[i]['MSE']
    total_MAE += prediction[i]['MAE']
    
avg_MSE = total_MSE/len(PoliceDistrict)
avg_MAE = total_MAE/len(PoliceDistrict)

print ('Average of Mean Squared Error = %s'%avg_MSE)
print ('Average of Mean Absolute Error = %s'%avg_MAE)
# Out:
# Mean Squared Error for district SOUTHEAST = 0.0
# Mean Absolute Error for district SOUTHEAST = 0.0
#
#
# Mean Squared Error for district NORTHWEST = 1.3792096513782978e-05
# Mean Absolute Error for district NORTHWEST = 0.0036925319226120052
#
#
# Mean Squared Error for district EASTERN = 0.07723725897752656
# Mean Absolute Error for district EASTERN = 0.13345209878651915
#
#
# Mean Squared Error for district NORTHERN = 0.0
# Mean Absolute Error for district NORTHERN = 0.0
#
#
# Mean Squared Error for district SOUTHERN = 1.0436341483661824e-05
# Mean Absolute Error for district SOUTHERN = 0.002738975869498208
#
#
# Mean Squared Error for district SOUTHWEST = 0.00020670187064550746
# Mean Absolute Error for district SOUTHWEST = 0.011174678381372522
#
#
# Mean Squared Error for district NORTHEAST = 0.0
# Mean Absolute Error for district NORTHEAST = 0.0
#
#
# Mean Squared Error for district WESTERN = 0.2329819422883019
# Mean Absolute Error for district WESTERN = 0.4192635175282234
#
#
# Mean Squared Error for district CENTRAL = 0.08160215245427921
# Mean Absolute Error for district CENTRAL = 0.11954776467364889
#
#
# Average of Mean Squared Error = 0.043561364892083405
# Average of Mean Absolute Error = 0.07665217412909714

# %% [markdown]
# #### Random Forest regressor prediction visualization

# %%
fig = plt.figure()

for i in range(0, 9):
    ax = '52%s'%(i+1)
    axis = fig.add_subplot(int(ax))
    y[i].plot(ax = axis, figsize = (15,20))
    plt.xlabel('Week', fontsize = 20)
    plt.ylabel('Crime', fontsize = 20)
    title = '%s District Predicted Crime Vs True Crime' % PoliceDistrict[i]
    plt.title(title, fontsize = 20)
    
fig.tight_layout(pad=3.0) 
plt.savefig('../../Graphs/Census_Data_As_Scale/Sub_Crime/%s/Predicted_Crime_Vs_True_Crime_RFR.jpg'%crime_type)

# %%
def write_to_csv(y, districts):
    for i in range(len(districts)):
        predicted = y[i]['Pred'].shift(1).iloc[285:].values
        predicted = pd.DataFrame(predicted, columns=[crime_type])
        #predicted = predicted.rename(columns={'Pred' : crime_type}) 
        try:
            csv = pd.read_csv('../../output/crime_per_10k/%s.csv'%districts[i])
            csv = pd.concat([csv, predicted], axis = 1)
        except:
            csv = pd.DataFrame()
            csv = pd.concat([csv, predicted], axis = 1)
        csv.to_csv('../../output/crime_per_10k/%s.csv'%districts[i], index = False)
        
districts = data['PoliceDistrict'].unique()
write_to_csv(y, districts)
